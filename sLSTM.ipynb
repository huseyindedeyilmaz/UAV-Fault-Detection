# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import glob 
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import VarianceThreshold
import torch
# Out:
# C:\Users\hy138\AppData\Local\Temp\ipykernel_19880\3508959855.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
def extract_topic_name(flight_name, file_name):
    topic_name = file_name.split(flight_name)
    topic_name =  topic_name[1].strip("-") if len(topic_name)>1 else ""
    topic_name = topic_name.split(".csv")[0]
    return topic_name

# %%
def read_data(full_path):
    df_tmp = pd.read_csv(full_path,on_bad_lines="skip")
    df_tmp = df_tmp.rename(columns={"%time": "timestamp"})
    
    df_tmp["timestamp"] = pd.to_datetime(df_tmp["timestamp"], unit="ns")
    df_tmp.set_index("timestamp", inplace=True) 
    return df_tmp

# %%
data_path = "./data/processed/"

# %%
unused_topic_list = ["diagnostics", "emergency_responder-traj_file","mavlink-from","mavros-state",
                    "global_position",
                     "local_position", 
                     "mavctrl-rpy",
                     "mavros-battery", "field_raw",
                     "mavros-imu-mag", "mavros-mission-reached",
                     "mavros-rc",
                      "setpoint_raw","mavros-imu-data_raw"]

unused_column_list = ["field.header.seq", "field.header.stamp", "field.header.frame_id", 
                      "field.commanded", "field.variance", "%time","field.x","field.twist.angular.x","field.twist.angular.y","field.twist.angular.z",
                      'field.orientation_covariance0',
       'field.orientation_covariance1',
       'field.orientation_covariance2',
       'field.orientation_covariance3',
       'field.orientation_covariance4',
       'field.orientation_covariance5',
       'field.orientation_covariance6',
       'field.orientation_covariance7',
       'field.orientation_covariance8',

       'field.angular_velocity_covariance0',
       'field.angular_velocity_covariance1',
       'field.angular_velocity_covariance2',
       'field.angular_velocity_covariance3',
       'field.angular_velocity_covariance4',
       'field.angular_velocity_covariance5',
       'field.angular_velocity_covariance6',
       'field.angular_velocity_covariance7',
       'field.angular_velocity_covariance8',

       'field.linear_acceleration_covariance0',
       'field.linear_acceleration_covariance1',
       'field.linear_acceleration_covariance2',
       'field.linear_acceleration_covariance3',
       'field.linear_acceleration_covariance4',
       'field.linear_acceleration_covariance5',
       'field.linear_acceleration_covariance6',
       'field.linear_acceleration_covariance7',
       'field.linear_acceleration_covariance8',
       "field.coordinate_frame","field.source"]

# %%
print(os.getcwd())
print(os.listdir())
# Out:
# c:\Users\hy138\Desktop\UAV
# ['.vscode', 'best_model.pth', 'BiLSTM.ipynb', 'BiLSTMs.ipynb', 'CNN1D.ipynb', 'CNN1Ds.ipynb', 'data', 'LSTM copy.ipynb', 'LSTM.ipynb', 'LSTMAutoEncoder.ipynb', 'LSTMs.ipynb', 'mLSTM.ipynb', 'sLSTM.ipynb', 'xLSTM.ipynb', 'Yeni klasör']

# %%
time_dict = {}
flight_topic_list = []
topic_list = []
all_columns = []
df_dict = {}
failure_status_dict = {}

# %%
print(topic_list)
# Out:
# []

# %%
for i,flight in enumerate(glob.glob(data_path+"*")):
    
    flight_name = os.path.basename(flight)
    
    if "no_ground_truth" in flight_name:
        continue
    if "no_failure" in flight_name:
            continue
    # This folder has not path-dev csv file
    if "carbonZ_2018-09-11-15-06-34_3_rudder_left_failure" in flight_name:
        continue
    print(flight_name)

    if flight_name not in flight_topic_list:
        flight_topic_list.append(flight_name)
    

    df_failure = None
    failure_duration_start = pd.Timestamp('1970-01-01')
    failure_duration_finish = pd.Timestamp('1970-01-01')

    dfs = list()
    for i , file in enumerate(glob.glob(os.path.join(data_path,flight_name,"*.csv"))):
        
        if any(x in file for x in unused_topic_list):
            continue
        

        if "failure_status" in os.path.basename(file):
            file_name = os.path.basename(file)
            
            df = read_data(file)
            topic_name = extract_topic_name(flight_name,file_name)

            
            failure_duration_start = min(df.index)
            failure_duration_end = max(df.index)

            failure_status_dict[flight_name] = (failure_duration_start,failure_duration_end)

            continue
        
        file_name = os.path.basename(file)

        df = read_data(file)
        topic_name = extract_topic_name(flight_name,file_name)
        for col in unused_column_list:
            if col in df.columns:
                df.drop(col,axis=1,inplace=True)
        new_columns = list(map(lambda x: f"{topic_name}.{x.replace('field.', '')}", df.columns))
        df = df.set_axis(new_columns, axis=1)
       
     
        
        dfs.append(df)

   
    df_dict[flight_name] = dfs
# Out:
# carbonZ_2018-07-18-15-53-31_1_engine_failure
# carbonZ_2018-07-18-15-53-31_2_engine_failure
# carbonZ_2018-07-18-16-22-01_engine_failure_with_emr_traj
# carbonZ_2018-07-18-16-37-39_2_engine_failure_with_emr_traj
# carbonZ_2018-07-30-16-29-45_engine_failure_with_emr_traj
# carbonZ_2018-07-30-16-39-00_1_engine_failure
# carbonZ_2018-07-30-16-39-00_2_engine_failure
# carbonZ_2018-07-30-17-10-45_engine_failure_with_emr_traj
# carbonZ_2018-07-30-17-20-01_engine_failure_with_emr_traj
# carbonZ_2018-07-30-17-36-35_engine_failure_with_emr_traj
# carbonZ_2018-07-30-17-46-31_engine_failure_with_emr_traj
# carbonZ_2018-09-11-11-56-30_engine_failure
# carbonZ_2018-09-11-14-22-07_1_engine_failure
# carbonZ_2018-09-11-14-22-07_2_engine_failure
# carbonZ_2018-09-11-14-41-51_elevator_failure
# carbonZ_2018-09-11-14-52-54_left_aileron__right_aileron__failure
# carbonZ_2018-09-11-15-05-11_1_elevator_failure
# carbonZ_2018-09-11-15-06-34_1_rudder_right_failure
# carbonZ_2018-09-11-15-06-34_2_rudder_right_failure
# carbonZ_2018-09-11-17-27-13_1_rudder_zero__left_aileron_failure
# carbonZ_2018-09-11-17-27-13_2_both_ailerons_failure
# carbonZ_2018-09-11-17-55-30_1_right_aileron_failure
# carbonZ_2018-09-11-17-55-30_2_left_aileron_failure
# carbonZ_2018-10-05-14-34-20_2_right_aileron_failure_with_emr_traj
# carbonZ_2018-10-05-14-37-22_2_right_aileron_failure
# carbonZ_2018-10-05-14-37-22_3_left_aileron_failure
# carbonZ_2018-10-05-15-52-12_3_engine_failure_with_emr_traj
# carbonZ_2018-10-05-15-55-10_engine_failure_with_emr_traj
# carbonZ_2018-10-05-16-04-46_engine_failure_with_emr_traj
# carbonZ_2018-10-18-11-03-57_engine_failure_with_emr_traj
# carbonZ_2018-10-18-11-04-00_engine_failure_with_emr_traj
# carbonZ_2018-10-18-11-04-08_1_engine_failure_with_emr_traj
# carbonZ_2018-10-18-11-04-08_2_engine_failure_with_emr_traj
# carbonZ_2018-10-18-11-04-35_engine_failure_with_emr_traj
# carbonZ_2018-10-18-11-06-06_engine_failure_with_emr_traj

# %%
len(df_dict["carbonZ_2018-07-18-15-53-31_1_engine_failure"])
# Out:
# 13

# %%
len(df_dict["carbonZ_2018-07-18-15-53-31_1_engine_failure"][0]),df_dict["carbonZ_2018-07-18-15-53-31_1_engine_failure"][0].isna().sum()
# Out:
# (6619,
#  mavctrl-path_dev.y    0
#  mavctrl-path_dev.z    0
#  dtype: int64)

# %%
failure_status_dict
# Out:
# {'carbonZ_2018-07-18-15-53-31_1_engine_failure': (Timestamp('2018-07-18 19:58:47.129305993'),
#   Timestamp('2018-07-18 19:59:03.134074845')),
#  'carbonZ_2018-07-18-15-53-31_2_engine_failure': (Timestamp('2018-07-18 20:01:44.729304590'),
#   Timestamp('2018-07-18 20:01:59.928010526')),
#  'carbonZ_2018-07-18-16-22-01_engine_failure_with_emr_traj': (Timestamp('2018-07-18 20:32:26.878396465'),
#   Timestamp('2018-07-18 20:32:42.672828037')),
#  'carbonZ_2018-07-18-16-37-39_2_engine_failure_with_emr_traj': (Timestamp('2018-07-18 20:46:37.888445250'),
#   Timestamp('2018-07-18 20:46:54.288954056')),
#  'carbonZ_2018-07-30-16-29-45_engine_failure_with_emr_traj': (Timestamp('2018-07-21 00:35:22.170194'),
#   Timestamp('2018-07-21 00:35:41.166058768')),
#  'carbonZ_2018-07-30-16-39-00_1_engine_failure': (Timestamp('2018-07-21 01:00:21.380769776'),
#   Timestamp('2018-07-21 01:00:36.175981200')),
#  'carbonZ_2018-07-30-16-39-00_2_engine_failure': (Timestamp('2018-07-21 01:04:00.575490608'),
#   Timestamp('2018-07-21 01:04:15.194122640')),
#  'carbonZ_2018-07-30-17-10-45_engine_failure_with_emr_traj': (Timestamp('2018-07-30 21:16:33.314179152'),
#   Timestamp('2018-07-30 21:16:49.124017251')),
#  'carbonZ_2018-07-30-17-20-01_engine_failure_with_emr_traj': (Timestamp('2018-07-30 21:25:25.757112162'),
#   Timestamp('2018-07-30 21:25:44.754748978')),
#  'carbonZ_2018-07-30-17-36-35_engine_failure_with_emr_traj': (Timestamp('2018-07-30 21:41:15.634859201'),
#   Timestamp('2018-07-30 21:41:39.036278834')),
#  'carbonZ_2018-07-30-17-46-31_engine_failure_with_emr_traj': (Timestamp('2018-07-30 21:49:47.539406723'),
#   Timestamp('2018-07-30 21:50:09.732858508')),
#  'carbonZ_2018-09-11-11-56-30_engine_failure': (Timestamp('2018-09-11 16:05:02.419301184'),
#   Timestamp('2018-09-11 16:05:22.921275104')),
#  'carbonZ_2018-09-11-14-22-07_1_engine_failure': (Timestamp('2018-09-11 18:26:14.324825782'),
#   Timestamp('2018-09-11 18:26:23.326658597')),
#  'carbonZ_2018-09-11-14-22-07_2_engine_failure': (Timestamp('2018-09-11 18:28:20.325374057'),
#   Timestamp('2018-09-11 18:28:32.326442789')),
#  'carbonZ_2018-09-11-14-41-51_elevator_failure': (Timestamp('2018-09-11 18:48:33.193239864'),
#   Timestamp('2018-09-11 18:48:43.702938424')),
#  'carbonZ_2018-09-11-14-52-54_left_aileron__right_aileron__failure': (Timestamp('2018-09-11 18:57:29.985030040'),
#   Timestamp('2018-09-11 18:59:37.993673016')),
#  'carbonZ_2018-09-11-15-05-11_1_elevator_failure': (Timestamp('2018-09-11 19:12:08.654835256'),
#   Timestamp('2018-09-11 19:12:21.172710456')),
#  'carbonZ_2018-09-11-15-06-34_1_rudder_right_failure': (Timestamp('2018-09-11 19:17:55.038442264'),
#   Timestamp('2018-09-11 19:18:09.537019480')),
#  'carbonZ_2018-09-11-15-06-34_2_rudder_right_failure': (Timestamp('2018-09-11 19:19:58.533612056'),
#   Timestamp('2018-09-11 19:20:15.542582552')),
#  'carbonZ_2018-09-11-17-27-13_1_rudder_zero__left_aileron_failure': (Timestamp('2018-09-11 21:36:15.255535472'),
#   Timestamp('2018-09-11 21:36:42.254787570')),
#  'carbonZ_2018-09-11-17-27-13_2_both_ailerons_failure': (Timestamp('2018-09-11 21:38:23.751688384'),
#   Timestamp('2018-09-11 21:38:59.249605331')),
#  'carbonZ_2018-09-11-17-55-30_1_right_aileron_failure': (Timestamp('2018-09-11 22:04:29.915932200'),
#   Timestamp('2018-09-11 22:04:50.916117253')),
#  'carbonZ_2018-09-11-17-55-30_2_left_aileron_failure': (Timestamp('2018-09-11 22:06:18.909972946'),
#   Timestamp('2018-09-11 22:06:49.930133544')),
#  'carbonZ_2018-10-05-14-34-20_2_right_aileron_failure_with_emr_traj': (Timestamp('2018-10-05 18:58:10.456220968'),
#   Timestamp('2018-10-05 18:58:19.953767048')),
#  'carbonZ_2018-10-05-14-37-22_2_right_aileron_failure': (Timestamp('2018-10-05 19:41:12.176343271'),
#   Timestamp('2018-10-05 19:42:23.177067207')),
#  'carbonZ_2018-10-05-14-37-22_3_left_aileron_failure': (Timestamp('2018-10-05 19:43:36.175449735'),
#   Timestamp('2018-10-05 19:44:00.176733447')),
#  'carbonZ_2018-10-05-15-52-12_3_engine_failure_with_emr_traj': (Timestamp('2018-10-05 20:07:04.743298528'),
#   Timestamp('2018-10-05 20:07:21.746703360')),
#  'carbonZ_2018-10-05-15-55-10_engine_failure_with_emr_traj': (Timestamp('2018-10-05 19:59:59.479181792'),
#   Timestamp('2018-10-05 20:00:12.477307424')),
#  'carbonZ_2018-10-05-16-04-46_engine_failure_with_emr_traj': (Timestamp('2018-10-05 20:09:30.477759008'),
#   Timestamp('2018-10-05 20:09:46.474778400')),
#  'carbonZ_2018-10-18-11-03-57_engine_failure_with_emr_traj': (Timestamp('2018-10-18 15:09:31.419064456'),
#   Timestamp('2018-10-18 15:09:43.416809576')),
#  'carbonZ_2018-10-18-11-04-00_engine_failure_with_emr_traj': (Timestamp('2018-10-18 15:09:27.628350888'),
#   Timestamp('2018-10-18 15:09:38.630940104')),
#  'carbonZ_2018-10-18-11-04-08_1_engine_failure_with_emr_traj': (Timestamp('2018-10-18 15:09:39.270985672'),
#   Timestamp('2018-10-18 15:09:53.269556136')),
#  'carbonZ_2018-10-18-11-04-08_2_engine_failure_with_emr_traj': (Timestamp('2018-10-18 15:19:45.268859464'),
#   Timestamp('2018-10-18 15:20:04.768932520')),
#  'carbonZ_2018-10-18-11-04-35_engine_failure_with_emr_traj': (Timestamp('2018-10-18 15:08:37.878232904'),
#   Timestamp('2018-10-18 15:08:45.380344968')),
#  'carbonZ_2018-10-18-11-06-06_engine_failure_with_emr_traj': (Timestamp('2018-10-18 15:12:17.734694408'),
#   Timestamp('2018-10-18 15:12:31.237794664'))}

# %%
# for key,data in df_dict.items():
#     df_list = []
#     for df in data:
#         for col in df.columns:
#             df[f'{col}_copy'] = df[col] 
    
#         df_list.append(df)
#     df_dict[key] = df_list

# %%
for key, df in df_dict.items():
    print(key)
    print(len(df))
# Out:
# carbonZ_2018-07-18-15-53-31_1_engine_failure
# 13
# carbonZ_2018-07-18-15-53-31_2_engine_failure
# 13
# carbonZ_2018-07-18-16-22-01_engine_failure_with_emr_traj
# 13
# carbonZ_2018-07-18-16-37-39_2_engine_failure_with_emr_traj
# 13
# carbonZ_2018-07-30-16-29-45_engine_failure_with_emr_traj
# 13
# carbonZ_2018-07-30-16-39-00_1_engine_failure
# 13
# carbonZ_2018-07-30-16-39-00_2_engine_failure
# 13
# carbonZ_2018-07-30-17-10-45_engine_failure_with_emr_traj
# 13
# carbonZ_2018-07-30-17-20-01_engine_failure_with_emr_traj
# 13
# carbonZ_2018-07-30-17-36-35_engine_failure_with_emr_traj
# 13
# carbonZ_2018-07-30-17-46-31_engine_failure_with_emr_traj
# 13
# carbonZ_2018-09-11-11-56-30_engine_failure
# 13
# carbonZ_2018-09-11-14-22-07_1_engine_failure
# 13
# carbonZ_2018-09-11-14-22-07_2_engine_failure
# 13
# carbonZ_2018-09-11-14-41-51_elevator_failure
# 13
# carbonZ_2018-09-11-14-52-54_left_aileron__right_aileron__failure
# 13
# carbonZ_2018-09-11-15-05-11_1_elevator_failure
# 13
# carbonZ_2018-09-11-15-06-34_1_rudder_right_failure
# 13
# carbonZ_2018-09-11-15-06-34_2_rudder_right_failure
# 13
# carbonZ_2018-09-11-17-27-13_1_rudder_zero__left_aileron_failure
# 13
# carbonZ_2018-09-11-17-27-13_2_both_ailerons_failure
# 13
# carbonZ_2018-09-11-17-55-30_1_right_aileron_failure
# 13
# carbonZ_2018-09-11-17-55-30_2_left_aileron_failure
# 13
# carbonZ_2018-10-05-14-34-20_2_right_aileron_failure_with_emr_traj
# 13
# carbonZ_2018-10-05-14-37-22_2_right_aileron_failure
# 13
# carbonZ_2018-10-05-14-37-22_3_left_aileron_failure
# 13
# carbonZ_2018-10-05-15-52-12_3_engine_failure_with_emr_traj
# 13
# carbonZ_2018-10-05-15-55-10_engine_failure_with_emr_traj
# 13
# carbonZ_2018-10-05-16-04-46_engine_failure_with_emr_traj
# 13
# carbonZ_2018-10-18-11-03-57_engine_failure_with_emr_traj
# 13
# carbonZ_2018-10-18-11-04-00_engine_failure_with_emr_traj
# 13
# carbonZ_2018-10-18-11-04-08_1_engine_failure_with_emr_traj
# 13
# carbonZ_2018-10-18-11-04-08_2_engine_failure_with_emr_traj
# 13
# carbonZ_2018-10-18-11-04-35_engine_failure_with_emr_traj
# 13
# carbonZ_2018-10-18-11-06-06_engine_failure_with_emr_traj
# 13

# %%
for key, data in df_dict.items():
    if "rudder_zero__left_aileron_failure" in key:
        

        df_dict["carbonZ_2018-09-11-17-27-13_1_rudder_zero_failure"] = df_dict['carbonZ_2018-09-11-17-27-13_1_rudder_zero__left_aileron_failure'].copy()
 
 

        df_dict["carbonZ_2018-09-11-17-27-13_1_left_aileron_failure"] = df_dict['carbonZ_2018-09-11-17-27-13_1_rudder_zero__left_aileron_failure'].copy()

   

        del df_dict['carbonZ_2018-09-11-17-27-13_1_rudder_zero__left_aileron_failure']


        break

# %%
for key, df in df_dict.items():
    print(key)
    print(len(df))
# Out:
# carbonZ_2018-07-18-15-53-31_1_engine_failure
# 13
# carbonZ_2018-07-18-15-53-31_2_engine_failure
# 13
# carbonZ_2018-07-18-16-22-01_engine_failure_with_emr_traj
# 13
# carbonZ_2018-07-18-16-37-39_2_engine_failure_with_emr_traj
# 13
# carbonZ_2018-07-30-16-29-45_engine_failure_with_emr_traj
# 13
# carbonZ_2018-07-30-16-39-00_1_engine_failure
# 13
# carbonZ_2018-07-30-16-39-00_2_engine_failure
# 13
# carbonZ_2018-07-30-17-10-45_engine_failure_with_emr_traj
# 13
# carbonZ_2018-07-30-17-20-01_engine_failure_with_emr_traj
# 13
# carbonZ_2018-07-30-17-36-35_engine_failure_with_emr_traj
# 13
# carbonZ_2018-07-30-17-46-31_engine_failure_with_emr_traj
# 13
# carbonZ_2018-09-11-11-56-30_engine_failure
# 13
# carbonZ_2018-09-11-14-22-07_1_engine_failure
# 13
# carbonZ_2018-09-11-14-22-07_2_engine_failure
# 13
# carbonZ_2018-09-11-14-41-51_elevator_failure
# 13
# carbonZ_2018-09-11-14-52-54_left_aileron__right_aileron__failure
# 13
# carbonZ_2018-09-11-15-05-11_1_elevator_failure
# 13
# carbonZ_2018-09-11-15-06-34_1_rudder_right_failure
# 13
# carbonZ_2018-09-11-15-06-34_2_rudder_right_failure
# 13
# carbonZ_2018-09-11-17-27-13_2_both_ailerons_failure
# 13
# carbonZ_2018-09-11-17-55-30_1_right_aileron_failure
# 13
# carbonZ_2018-09-11-17-55-30_2_left_aileron_failure
# 13
# carbonZ_2018-10-05-14-34-20_2_right_aileron_failure_with_emr_traj
# 13
# carbonZ_2018-10-05-14-37-22_2_right_aileron_failure
# 13
# carbonZ_2018-10-05-14-37-22_3_left_aileron_failure
# 13
# carbonZ_2018-10-05-15-52-12_3_engine_failure_with_emr_traj
# 13
# carbonZ_2018-10-05-15-55-10_engine_failure_with_emr_traj
# 13
# carbonZ_2018-10-05-16-04-46_engine_failure_with_emr_traj
# 13
# carbonZ_2018-10-18-11-03-57_engine_failure_with_emr_traj
# 13
# carbonZ_2018-10-18-11-04-00_engine_failure_with_emr_traj
# 13
# carbonZ_2018-10-18-11-04-08_1_engine_failure_with_emr_traj
# 13
# carbonZ_2018-10-18-11-04-08_2_engine_failure_with_emr_traj
# 13
# carbonZ_2018-10-18-11-04-35_engine_failure_with_emr_traj
# 13
# carbonZ_2018-10-18-11-06-06_engine_failure_with_emr_traj
# 13
# carbonZ_2018-09-11-17-27-13_1_rudder_zero_failure
# 13
# carbonZ_2018-09-11-17-27-13_1_left_aileron_failure
# 13

# %%
for key, data in failure_status_dict.items():
    if "rudder_zero__left_aileron_failure" in key:
        failure_status_dict["carbonZ_2018-09-11-17-27-13_1_rudder_zero_failure"] = failure_status_dict["carbonZ_2018-09-11-17-27-13_1_rudder_zero__left_aileron_failure"]
        failure_status_dict["carbonZ_2018-09-11-17-27-13_1_left_aileron_failure"] = failure_status_dict["carbonZ_2018-09-11-17-27-13_1_rudder_zero__left_aileron_failure"]
        del failure_status_dict["carbonZ_2018-09-11-17-27-13_1_rudder_zero__left_aileron_failure"]
        break

# %%
df_dict["carbonZ_2018-09-11-17-27-13_1_rudder_zero_failure"][1].columns
# Out:
# Index(['mavros-imu-atm_pressure.fluid_pressure'], dtype='object')

# %%
df_dict["carbonZ_2018-07-18-15-53-31_1_engine_failure"][0]
# Out:
#                                mavctrl-path_dev.y  mavctrl-path_dev.z
# timestamp
# 2018-07-18 19:56:50.820860792          141.284886           14.438259
# 2018-07-18 19:56:50.840917944          141.284886           14.438259
# 2018-07-18 19:56:50.861388914          141.284886           14.438259
# 2018-07-18 19:56:50.880812090          141.284886           14.438259
# 2018-07-18 19:56:50.901712334          144.798264           14.394005
# ...                                           ...                 ...
# 2018-07-18 19:59:03.108804965            8.337481           21.670137
# 2018-07-18 19:59:03.130722624            8.337481           21.670137
# 2018-07-18 19:59:03.149511356            8.337481           21.670137
# 2018-07-18 19:59:03.171009244            8.337481           21.670137
# 2018-07-18 19:59:03.190838957            8.337481           21.670137
#
# [6619 rows x 2 columns]

# %%
flight_topic_list.append("carbonZ_2018-09-11-17-27-13_1_rudder_zero_failure")
flight_topic_list.append("carbonZ_2018-09-11-17-27-13_1_left_aileron_failure")
flight_topic_list.remove("carbonZ_2018-09-11-17-27-13_1_rudder_zero__left_aileron_failure")

# %%
len(flight_topic_list)
# Out:
# 36

# %%
failure_status_dict["carbonZ_2018-07-18-15-53-31_1_engine_failure"]
# Out:
# (Timestamp('2018-07-18 19:58:47.129305993'),
#  Timestamp('2018-07-18 19:59:03.134074845'))

# %%
df = df_dict["carbonZ_2018-09-11-14-52-54_left_aileron__right_aileron__failure"]
df
# Out:
# [                               mavctrl-path_dev.y  mavctrl-path_dev.z
#  timestamp
#  2018-09-11 18:55:44.748852696          226.349940          -16.530594
#  2018-09-11 18:55:44.768693912          226.349940          -16.530594
#  2018-09-11 18:55:44.793884088          207.499653          -16.530594
#  2018-09-11 18:55:44.809683352          207.499366          -16.530594
#  2018-09-11 18:55:44.831660792          207.499366          -16.530594
#  ...                                           ...                 ...
#  2018-09-11 18:59:38.029159576            5.033987            3.622774
#  2018-09-11 18:59:38.049874936            5.033987            3.622774
#  2018-09-11 18:59:38.073666904            5.033987            3.622774
#  2018-09-11 18:59:38.089277368            4.698973            4.732197
#  2018-09-11 18:59:38.109449304            4.698973            4.732197
#
#  [11669 rows x 2 columns],
#                                 mavros-imu-atm_pressure.fluid_pressure
#  timestamp
#  2018-09-11 18:55:44.739465240                            97497.888184
#  2018-09-11 18:55:44.821564344                            97497.888184
#  2018-09-11 18:55:44.938280408                            97485.864258
#  2018-09-11 18:55:45.038424536                            97479.797363
#  2018-09-11 18:55:45.123441848                            97479.797363
#  ...                                                               ...
#  2018-09-11 18:59:37.626786712                            97689.019775
#  2018-09-11 18:59:37.734683928                            97696.691895
#  2018-09-11 18:59:37.833203736                            97704.296875
#  2018-09-11 18:59:37.924305528                            97704.296875
#  2018-09-11 18:59:38.018054744                            97711.303711
#
#  [2334 rows x 1 columns],
#                                 mavros-imu-data.orientation.x  \
#  timestamp
#  2018-09-11 18:55:44.815328696                      -0.005702
#  2018-09-11 18:55:45.302239320                      -0.027779
#  2018-09-11 18:55:45.691413272                      -0.004409
#  2018-09-11 18:55:46.060852152                       0.022710
#  2018-09-11 18:55:46.443526008                       0.048855
#  ...                                                      ...
#  2018-09-11 18:59:36.240079096                      -0.120860
#  2018-09-11 18:59:36.683336696                      -0.126285
#  2018-09-11 18:59:37.197629496                      -0.091700
#  2018-09-11 18:59:37.632176952                      -0.057563
#  2018-09-11 18:59:37.978509688                      -0.021296
#
#                                 mavros-imu-data.orientation.y  \
#  timestamp
#  2018-09-11 18:55:44.815328696                      -0.024376
#  2018-09-11 18:55:45.302239320                      -0.232940
#  2018-09-11 18:55:45.691413272                      -0.276876
#  2018-09-11 18:55:46.060852152                      -0.314628
#  2018-09-11 18:55:46.443526008                      -0.314407
#  ...                                                      ...
#  2018-09-11 18:59:36.240079096                      -0.012206
#  2018-09-11 18:59:36.683336696                      -0.054971
#  2018-09-11 18:59:37.197629496                      -0.115521
#  2018-09-11 18:59:37.632176952                      -0.169438
#  2018-09-11 18:59:37.978509688                      -0.193174
#
#                                 mavros-imu-data.orientation.z  \
#  timestamp
#  2018-09-11 18:55:44.815328696                      -0.986004
#  2018-09-11 18:55:45.302239320                      -0.958538
#  2018-09-11 18:55:45.691413272                      -0.941414
#  2018-09-11 18:55:46.060852152                      -0.920235
#  2018-09-11 18:55:46.443526008                      -0.909142
#  ...                                                      ...
#  2018-09-11 18:59:36.240079096                      -0.003183
#  2018-09-11 18:59:36.683336696                       0.015267
#  2018-09-11 18:59:37.197629496                       0.006238
#  2018-09-11 18:59:37.632176952                       0.018558
#  2018-09-11 18:59:37.978509688                       0.032839
#
#                                 mavros-imu-data.orientation.w  \
#  timestamp
#  2018-09-11 18:55:44.815328696                      -0.164833
#  2018-09-11 18:55:45.302239320                      -0.161779
#  2018-09-11 18:55:45.691413272                      -0.192508
#  2018-09-11 18:55:46.060852152                      -0.231648
#  2018-09-11 18:55:46.443526008                      -0.268742
#  ...                                                      ...
#  2018-09-11 18:59:36.240079096                      -0.992589
#  2018-09-11 18:59:36.683336696                      -0.990352
#  2018-09-11 18:59:37.197629496                      -0.989044
#  2018-09-11 18:59:37.632176952                      -0.983683
#  2018-09-11 18:59:37.978509688                      -0.980384
#
#                                 mavros-imu-data.angular_velocity.x  \
#  timestamp
#  2018-09-11 18:55:44.815328696                            1.198352
#  2018-09-11 18:55:45.302239320                            0.344504
#  2018-09-11 18:55:45.691413272                            0.204759
#  2018-09-11 18:55:46.060852152                           -0.013796
#  2018-09-11 18:55:46.443526008                           -0.006801
#  ...                                                           ...
#  2018-09-11 18:59:36.240079096                            0.044647
#  2018-09-11 18:59:36.683336696                            0.073532
#  2018-09-11 18:59:37.197629496                           -0.298716
#  2018-09-11 18:59:37.632176952                           -0.146525
#  2018-09-11 18:59:37.978509688                           -0.147029
#
#                                 mavros-imu-data.angular_velocity.y  \
#  timestamp
#  2018-09-11 18:55:44.815328696                           -0.003927
#  2018-09-11 18:55:45.302239320                            0.093244
#  2018-09-11 18:55:45.691413272                            0.108409
#  2018-09-11 18:55:46.060852152                            0.087250
#  2018-09-11 18:55:46.443526008                            0.039049
#  ...                                                           ...
#  2018-09-11 18:59:36.240079096                            0.161116
#  2018-09-11 18:59:36.683336696                            0.198077
#  2018-09-11 18:59:37.197629496                            0.236909
#  2018-09-11 18:59:37.632176952                            0.182599
#  2018-09-11 18:59:37.978509688                            0.090268
#
#                                 mavros-imu-data.angular_velocity.z  \
#  timestamp
#  2018-09-11 18:55:44.815328696                           -0.046569
#  2018-09-11 18:55:45.302239320                           -0.081719
#  2018-09-11 18:55:45.691413272                           -0.277471
#  2018-09-11 18:55:46.060852152                           -0.250878
#  2018-09-11 18:55:46.443526008                           -0.169687
#  ...                                                           ...
#  2018-09-11 18:59:36.240079096                           -0.134020
#  2018-09-11 18:59:36.683336696                           -0.064672
#  2018-09-11 18:59:37.197629496                            0.000992
#  2018-09-11 18:59:37.632176952                           -0.147860
#  2018-09-11 18:59:37.978509688                           -0.082429
#
#                                 mavros-imu-data.linear_acceleration.x  \
#  timestamp
#  2018-09-11 18:55:44.815328696                              -0.402073
#  2018-09-11 18:55:45.302239320                              -1.353318
#  2018-09-11 18:55:45.691413272                              -1.637711
#  2018-09-11 18:55:46.060852152                              -1.980943
#  2018-09-11 18:55:46.443526008                              -2.216303
#  ...                                                              ...
#  2018-09-11 18:59:36.240079096                              -0.529559
#  2018-09-11 18:59:36.683336696                              -1.108151
#  2018-09-11 18:59:37.197629496                              -1.353318
#  2018-09-11 18:59:37.632176952                              -1.520031
#  2018-09-11 18:59:37.978509688                              -1.696550
#
#                                 mavros-imu-data.linear_acceleration.y  \
#  timestamp
#  2018-09-11 18:55:44.815328696                               0.127486
#  2018-09-11 18:55:45.302239320                               0.539366
#  2018-09-11 18:55:45.691413272                               0.480526
#  2018-09-11 18:55:46.060852152                               0.647239
#  2018-09-11 18:55:46.443526008                               0.931632
#  ...                                                              ...
#  2018-09-11 18:59:36.240079096                               0.323619
#  2018-09-11 18:59:36.683336696                               0.421686
#  2018-09-11 18:59:37.197629496                               0.823759
#  2018-09-11 18:59:37.632176952                               0.657046
#  2018-09-11 18:59:37.978509688                               0.049033
#
#                                 mavros-imu-data.linear_acceleration.z
#  timestamp
#  2018-09-11 18:55:44.815328696                               8.463139
#  2018-09-11 18:55:45.302239320                               7.874740
#  2018-09-11 18:55:45.691413272                               4.138406
#  2018-09-11 18:55:46.060852152                               5.864377
#  2018-09-11 18:55:46.443526008                               7.757060
#  ...                                                              ...
#  2018-09-11 18:59:36.240079096                               7.678607
#  2018-09-11 18:59:36.683336696                               6.246836
#  2018-09-11 18:59:37.197629496                               5.060231
#  2018-09-11 18:59:37.632176952                               4.501252
#  2018-09-11 18:59:37.978509688                               7.139241
#
#  [574 rows x 10 columns],
#                                 mavros-imu-temperature.temperature
#  timestamp
#  2018-09-11 18:55:44.739417624                               41.89
#  2018-09-11 18:55:44.821516824                               41.89
#  2018-09-11 18:55:44.938254904                               41.88
#  2018-09-11 18:55:45.038322712                               41.87
#  2018-09-11 18:55:45.123392344                               41.87
#  ...                                                           ...
#  2018-09-11 18:59:37.626645912                               37.06
#  2018-09-11 18:59:37.734617272                               37.05
#  2018-09-11 18:59:37.833124216                               37.05
#  2018-09-11 18:59:37.924084376                               37.05
#  2018-09-11 18:59:38.018026488                               37.06
#
#  [2334 rows x 1 columns],
#                                 mavros-nav_info-airspeed.measured
#  timestamp
#  2018-09-11 18:55:44.751156440                                0.0
#  2018-09-11 18:55:44.811619032                                0.0
#  2018-09-11 18:55:44.837812728                                0.0
#  2018-09-11 18:55:44.900119192                                0.0
#  2018-09-11 18:55:44.965182744                                0.0
#  ...                                                          ...
#  2018-09-11 18:59:37.860557656                                0.0
#  2018-09-11 18:59:37.920680280                                0.0
#  2018-09-11 18:59:37.974660856                                0.0
#  2018-09-11 18:59:38.013118776                                0.0
#  2018-09-11 18:59:38.073726968                                0.0
#
#  [4348 rows x 1 columns],
#                                 mavros-nav_info-errors.alt_error  \
#  timestamp
#  2018-09-11 18:55:44.733756664                         -0.300000
#  2018-09-11 18:55:44.747403736                         -0.300000
#  2018-09-11 18:55:44.786480952                         -0.300000
#  2018-09-11 18:55:44.836539000                         -0.430000
#  2018-09-11 18:55:44.898553720                         -0.430000
#  ...                                                         ...
#  2018-09-11 18:59:37.860320760                         20.289999
#  2018-09-11 18:59:37.917356952                         20.289999
#  2018-09-11 18:59:37.969003608                         20.859999
#  2018-09-11 18:59:38.011773848                         20.859999
#  2018-09-11 18:59:38.057258392                         21.469999
#
#                                 mavros-nav_info-errors.aspd_error  \
#  timestamp
#  2018-09-11 18:55:44.733756664                        -681.648438
#  2018-09-11 18:55:44.747403736                        -681.648438
#  2018-09-11 18:55:44.786480952                        -681.648438
#  2018-09-11 18:55:44.836539000                        -684.812134
#  2018-09-11 18:55:44.898553720                        -684.812134
#  ...                                                          ...
#  2018-09-11 18:59:37.860320760                         -41.753960
#  2018-09-11 18:59:37.917356952                         -41.753960
#  2018-09-11 18:59:37.969003608                         -41.753960
#  2018-09-11 18:59:38.011773848                         -41.753960
#  2018-09-11 18:59:38.057258392                         -42.135429
#
#                                 mavros-nav_info-errors.xtrack_error  \
#  timestamp
#  2018-09-11 18:55:44.733756664                           -40.078075
#  2018-09-11 18:55:44.747403736                           -40.078075
#  2018-09-11 18:55:44.786480952                           -40.078075
#  2018-09-11 18:55:44.836539000                           -37.936432
#  2018-09-11 18:55:44.898553720                           -37.936432
#  ...                                                            ...
#  2018-09-11 18:59:37.860320760                             5.042744
#  2018-09-11 18:59:37.917356952                             5.042744
#  2018-09-11 18:59:37.969003608                             4.909161
#  2018-09-11 18:59:38.011773848                             4.909161
#  2018-09-11 18:59:38.057258392                             4.764447
#
#                                 mavros-nav_info-errors.wp_dist
#  timestamp
#  2018-09-11 18:55:44.733756664                               4
#  2018-09-11 18:55:44.747403736                               4
#  2018-09-11 18:55:44.786480952                               4
#  2018-09-11 18:55:44.836539000                               6
#  2018-09-11 18:55:44.898553720                               6
#  ...                                                       ...
#  2018-09-11 18:59:37.860320760                             165
#  2018-09-11 18:59:37.917356952                             165
#  2018-09-11 18:59:37.969003608                             165
#  2018-09-11 18:59:38.011773848                             165
#  2018-09-11 18:59:38.057258392                             165
#
#  [4440 rows x 4 columns],
#                                 mavros-nav_info-pitch.measured
#  timestamp
#  2018-09-11 18:55:44.733683000                        0.797831
#  2018-09-11 18:55:44.747360408                        0.797831
#  2018-09-11 18:55:44.786440792                        0.797831
#  2018-09-11 18:55:44.836514104                        0.183815
#  2018-09-11 18:55:44.898461464                        0.183815
#  ...                                                       ...
#  2018-09-11 18:59:37.860291352                      -19.601870
#  2018-09-11 18:59:37.917281208                      -19.601870
#  2018-09-11 18:59:37.967814840                      -19.601870
#  2018-09-11 18:59:38.011744568                      -22.344082
#  2018-09-11 18:59:38.057027960                      -22.344082
#
#  [4440 rows x 1 columns],
#                                 mavros-nav_info-roll.measured
#  timestamp
#  2018-09-11 18:55:44.733653240                     -11.961676
#  2018-09-11 18:55:44.747348664                     -11.961676
#  2018-09-11 18:55:44.785582360                     -11.961676
#  2018-09-11 18:55:44.836487064                       2.863091
#  2018-09-11 18:55:44.898428952                       2.863091
#  ...                                                      ...
#  2018-09-11 18:59:37.917263992                       6.519372
#  2018-09-11 18:59:37.967593688                       6.519372
#  2018-09-11 18:59:38.011726584                       1.801064
#  2018-09-11 18:59:38.056942072                       1.801064
#  2018-09-11 18:59:38.118799704                       1.801064
#
#  [4441 rows x 1 columns],
#                                 mavros-nav_info-velocity.des_x  \
#  timestamp
#  2018-09-11 18:55:44.751172664                    0.000000e+00
#  2018-09-11 18:55:44.811629816                    0.000000e+00
#  2018-09-11 18:55:44.837833816                    0.000000e+00
#  2018-09-11 18:55:44.900179000                    1.600000e+01
#  2018-09-11 18:55:44.964750008                    1.600000e+01
#  ...                                                       ...
#  2018-09-11 18:59:37.860689592                    3.199951e-15
#  2018-09-11 18:59:37.920835864                    3.169954e-15
#  2018-09-11 18:59:37.974727832                    3.169954e-15
#  2018-09-11 18:59:38.013186072                    3.169954e-15
#  2018-09-11 18:59:38.073708088                    3.169954e-15
#
#                                 mavros-nav_info-velocity.des_y  \
#  timestamp
#  2018-09-11 18:55:44.751172664                    0.000000e+00
#  2018-09-11 18:55:44.811629816                    0.000000e+00
#  2018-09-11 18:55:44.837833816                    0.000000e+00
#  2018-09-11 18:55:44.900179000                   -3.552714e-15
#  2018-09-11 18:55:44.964750008                   -3.552714e-15
#  ...                                                       ...
#  2018-09-11 18:59:37.860689592                    1.580050e+01
#  2018-09-11 18:59:37.920835864                    1.576931e+01
#  2018-09-11 18:59:37.974727832                    1.576931e+01
#  2018-09-11 18:59:38.013186072                    1.576931e+01
#  2018-09-11 18:59:38.073708088                    1.576931e+01
#
#                                 mavros-nav_info-velocity.des_z  \
#  timestamp
#  2018-09-11 18:55:44.751172664                    0.000000e+00
#  2018-09-11 18:55:44.811629816                    0.000000e+00
#  2018-09-11 18:55:44.837833816                    0.000000e+00
#  2018-09-11 18:55:44.900179000                    1.959435e-15
#  2018-09-11 18:55:44.964750008                    1.959435e-15
#  ...                                                       ...
#  2018-09-11 18:59:37.860689592                    2.518796e+00
#  2018-09-11 18:59:37.920835864                    2.707196e+00
#  2018-09-11 18:59:37.974727832                    2.707196e+00
#  2018-09-11 18:59:38.013186072                    2.707196e+00
#  2018-09-11 18:59:38.073708088                    2.707196e+00
#
#                                 mavros-nav_info-velocity.meas_x  \
#  timestamp
#  2018-09-11 18:55:44.751172664                         5.448525
#  2018-09-11 18:55:44.811629816                         5.435284
#  2018-09-11 18:55:44.837833816                         5.446200
#  2018-09-11 18:55:44.900179000                         5.503401
#  2018-09-11 18:55:44.964750008                         5.601675
#  ...                                                        ...
#  2018-09-11 18:59:37.860689592                        -1.700567
#  2018-09-11 18:59:37.920835864                        -1.696898
#  2018-09-11 18:59:37.974727832                        -1.686711
#  2018-09-11 18:59:38.013186072                        -1.687362
#  2018-09-11 18:59:38.073708088                        -1.674494
#
#                                 mavros-nav_info-velocity.meas_y  \
#  timestamp
#  2018-09-11 18:55:44.751172664                       -20.630127
#  2018-09-11 18:55:44.811629816                       -20.569389
#  2018-09-11 18:55:44.837833816                       -20.520662
#  2018-09-11 18:55:44.900179000                       -20.415331
#  2018-09-11 18:55:44.964750008                       -20.283449
#  ...                                                        ...
#  2018-09-11 18:59:37.860689592                        16.762850
#  2018-09-11 18:59:37.920835864                        16.808422
#  2018-09-11 18:59:37.974727832                        16.851337
#  2018-09-11 18:59:38.013186072                        16.912659
#  2018-09-11 18:59:38.073708088                        17.052553
#
#                                 mavros-nav_info-velocity.meas_z
#  timestamp
#  2018-09-11 18:55:44.751172664                        -1.310496
#  2018-09-11 18:55:44.811629816                        -1.264987
#  2018-09-11 18:55:44.837833816                        -1.268989
#  2018-09-11 18:55:44.900179000                        -1.315569
#  2018-09-11 18:55:44.964750008                        -1.351536
#  ...                                                        ...
#  2018-09-11 18:59:37.860689592                         5.994641
#  2018-09-11 18:59:37.920835864                         6.185676
#  2018-09-11 18:59:37.974727832                         6.284477
#  2018-09-11 18:59:38.013186072                         6.342451
#  2018-09-11 18:59:38.073708088                         6.416114
#
#  [4348 rows x 6 columns],
#                                 mavros-nav_info-yaw.measured
#  timestamp
#  2018-09-11 18:55:44.733721848                    -70.156189
#  2018-09-11 18:55:44.747371832                    -70.156189
#  2018-09-11 18:55:44.786465720                    -70.156189
#  2018-09-11 18:55:44.836527032                    -71.014297
#  2018-09-11 18:55:44.898478872                    -71.014297
#  ...                                                     ...
#  2018-09-11 18:59:37.860307032                     91.034180
#  2018-09-11 18:59:37.917339416                     91.034180
#  2018-09-11 18:59:37.967848504                     91.034180
#  2018-09-11 18:59:38.011759000                     93.481194
#  2018-09-11 18:59:38.057181560                     93.481194
#
#  [4440 rows x 1 columns],
#                                 mavros-time_reference.time_ref
#  timestamp
#  2018-09-11 18:55:44.736821976             1536692377361000000
#  2018-09-11 18:55:45.206083608             1536692377841000000
#  2018-09-11 18:55:45.815905752             1536692378440000000
#  2018-09-11 18:55:46.251725048             1536692378879000000
#  2018-09-11 18:55:46.631150328             1536692379261000000
#  ...                                                       ...
#  2018-09-11 18:59:35.671488152             1536692608301000000
#  2018-09-11 18:59:36.138563064             1536692608778000000
#  2018-09-11 18:59:36.746569464             1536692609360000000
#  2018-09-11 18:59:37.272394168             1536692609917000000
#  2018-09-11 18:59:37.862205048             1536692610500000000
#
#  [477 rows x 1 columns],
#                                 mavros-vfr_hud.airspeed  \
#  timestamp
#  2018-09-11 18:55:44.813606648                      0.0
#  2018-09-11 18:55:45.288424728                      0.0
#  2018-09-11 18:55:45.689541272                      0.0
#  2018-09-11 18:55:46.059403576                      0.0
#  2018-09-11 18:55:46.439877208                      0.0
#  ...                                                ...
#  2018-09-11 18:59:36.236687256                      0.0
#  2018-09-11 18:59:36.682041176                      0.0
#  2018-09-11 18:59:37.193585176                      0.0
#  2018-09-11 18:59:37.628674168                      0.0
#  2018-09-11 18:59:37.976107736                      0.0
#
#                                 mavros-vfr_hud.groundspeed  \
#  timestamp
#  2018-09-11 18:55:44.813606648                   21.275387
#  2018-09-11 18:55:45.288424728                   20.532625
#  2018-09-11 18:55:45.689541272                   19.939848
#  2018-09-11 18:55:46.059403576                   19.413969
#  2018-09-11 18:55:46.439877208                   19.055178
#  ...                                                   ...
#  2018-09-11 18:59:36.236687256                   17.511122
#  2018-09-11 18:59:36.682041176                   17.207243
#  2018-09-11 18:59:37.193585176                   16.966467
#  2018-09-11 18:59:37.628674168                   16.777716
#  2018-09-11 18:59:37.976107736                   16.935541
#
#                                 mavros-vfr_hud.heading  \
#  timestamp
#  2018-09-11 18:55:44.813606648                     288
#  2018-09-11 18:55:45.288424728                     288
#  2018-09-11 18:55:45.689541272                     291
#  2018-09-11 18:55:46.059403576                     294
#  2018-09-11 18:55:46.439877208                     298
#  ...                                               ...
#  2018-09-11 18:59:36.236687256                      89
#  2018-09-11 18:59:36.682041176                      90
#  2018-09-11 18:59:37.193585176                      89
#  2018-09-11 18:59:37.628674168                      91
#  2018-09-11 18:59:37.976107736                      93
#
#                                 mavros-vfr_hud.throttle  \
#  timestamp
#  2018-09-11 18:55:44.813606648                     0.42
#  2018-09-11 18:55:45.288424728                     0.31
#  2018-09-11 18:55:45.689541272                     0.19
#  2018-09-11 18:55:46.059403576                     0.13
#  2018-09-11 18:55:46.439877208                     0.07
#  ...                                                ...
#  2018-09-11 18:59:36.236687256                     0.28
#  2018-09-11 18:59:36.682041176                     0.13
#  2018-09-11 18:59:37.193585176                     0.02
#  2018-09-11 18:59:37.628674168                     0.00
#  2018-09-11 18:59:37.976107736                     0.00
#
#                                 mavros-vfr_hud.altitude  mavros-vfr_hud.climb
#  timestamp
#  2018-09-11 18:55:44.813606648               410.979980              2.028334
#  2018-09-11 18:55:45.288424728               411.619995              5.472738
#  2018-09-11 18:55:45.689541272               411.729980              2.834411
#  2018-09-11 18:55:46.059403576               411.119995             -0.804450
#  2018-09-11 18:55:46.439877208               409.899994             -2.400985
#  ...                                                ...                   ...
#  2018-09-11 18:59:36.236687256               393.539978              3.508874
#  2018-09-11 18:59:36.682041176               393.690002              2.542262
#  2018-09-11 18:59:37.193585176               393.039978              0.578386
#  2018-09-11 18:59:37.628674168               391.380005             -2.801878
#  2018-09-11 18:59:37.976107736               389.500000             -4.096410
#
#  [574 rows x 6 columns],
#                                 mavros-wind_estimation.twist.linear.x  \
#  timestamp
#  2018-09-11 18:55:44.735729400                              -0.244657
#  2018-09-11 18:55:45.204481688                              -0.246626
#  2018-09-11 18:55:45.815334840                              -0.256024
#  2018-09-11 18:55:46.251742712                              -0.263208
#  2018-09-11 18:55:46.630086456                              -0.272890
#  ...                                                              ...
#  2018-09-11 18:59:35.669880760                              -0.392364
#  2018-09-11 18:59:36.137095000                              -0.391501
#  2018-09-11 18:59:36.745169944                              -0.392030
#  2018-09-11 18:59:37.272128440                              -0.391855
#  2018-09-11 18:59:37.860959800                              -0.388418
#
#                                 mavros-wind_estimation.twist.linear.y  \
#  timestamp
#  2018-09-11 18:55:44.735729400                               1.064529
#  2018-09-11 18:55:45.204481688                               1.066408
#  2018-09-11 18:55:45.815334840                               1.059074
#  2018-09-11 18:55:46.251742712                               1.054658
#  2018-09-11 18:55:46.630086456                               1.050315
#  ...                                                              ...
#  2018-09-11 18:59:35.669880760                               1.266036
#  2018-09-11 18:59:36.137095000                               1.265149
#  2018-09-11 18:59:36.745169944                               1.257739
#  2018-09-11 18:59:37.272128440                               1.251944
#  2018-09-11 18:59:37.860959800                               1.251336
#
#                                 mavros-wind_estimation.twist.linear.z
#  timestamp
#  2018-09-11 18:55:44.735729400                                    0.0
#  2018-09-11 18:55:45.204481688                                    0.0
#  2018-09-11 18:55:45.815334840                                    0.0
#  2018-09-11 18:55:46.251742712                                    0.0
#  2018-09-11 18:55:46.630086456                                    0.0
#  ...                                                              ...
#  2018-09-11 18:59:35.669880760                                    0.0
#  2018-09-11 18:59:36.137095000                                    0.0
#  2018-09-11 18:59:36.745169944                                    0.0
#  2018-09-11 18:59:37.272128440                                    0.0
#  2018-09-11 18:59:37.860959800                                    0.0
#
#  [477 rows x 3 columns]]

# %% [markdown]
# Failure Status:
#
#     Engine     = 1
#     Rudder     = 2
#     Aileron    = 3
#     Elevator   = 4

# %%
def add_failure(flight_name,df_failure,failure_duration_start,failure_duration_end):
    if "engine" in flight_name:
        failure_status = [
        1 if (x > failure_duration_start and x < failure_duration_end) else 0 
        for x in df_failure.index
                ]
    elif "rudder" in flight_name:
        failure_status = [
        2 if (x > failure_duration_start and x < failure_duration_end) else 0 
        for x in df_failure.index
                ]
    elif "aileron" in flight_name:
        failure_status = [
        3 if (x > failure_duration_start and x < failure_duration_end) else 0 
        for x in df_failure.index
                ]
    elif "elevator" in flight_name:
        failure_status = [
        4 if (x > failure_duration_start and x < failure_duration_end) else 0 
        for x in df_failure.index
                ]
        
    df_failure["failure_status"] = failure_status
        
    return df_failure

# %%
flight_topic_list
# Out:
# ['carbonZ_2018-07-18-15-53-31_1_engine_failure',
#  'carbonZ_2018-07-18-15-53-31_2_engine_failure',
#  'carbonZ_2018-07-18-16-22-01_engine_failure_with_emr_traj',
#  'carbonZ_2018-07-18-16-37-39_2_engine_failure_with_emr_traj',
#  'carbonZ_2018-07-30-16-29-45_engine_failure_with_emr_traj',
#  'carbonZ_2018-07-30-16-39-00_1_engine_failure',
#  'carbonZ_2018-07-30-16-39-00_2_engine_failure',
#  'carbonZ_2018-07-30-17-10-45_engine_failure_with_emr_traj',
#  'carbonZ_2018-07-30-17-20-01_engine_failure_with_emr_traj',
#  'carbonZ_2018-07-30-17-36-35_engine_failure_with_emr_traj',
#  'carbonZ_2018-07-30-17-46-31_engine_failure_with_emr_traj',
#  'carbonZ_2018-09-11-11-56-30_engine_failure',
#  'carbonZ_2018-09-11-14-22-07_1_engine_failure',
#  'carbonZ_2018-09-11-14-22-07_2_engine_failure',
#  'carbonZ_2018-09-11-14-41-51_elevator_failure',
#  'carbonZ_2018-09-11-14-52-54_left_aileron__right_aileron__failure',
#  'carbonZ_2018-09-11-15-05-11_1_elevator_failure',
#  'carbonZ_2018-09-11-15-06-34_1_rudder_right_failure',
#  'carbonZ_2018-09-11-15-06-34_2_rudder_right_failure',
#  'carbonZ_2018-09-11-17-27-13_2_both_ailerons_failure',
#  'carbonZ_2018-09-11-17-55-30_1_right_aileron_failure',
#  'carbonZ_2018-09-11-17-55-30_2_left_aileron_failure',
#  'carbonZ_2018-10-05-14-34-20_2_right_aileron_failure_with_emr_traj',
#  'carbonZ_2018-10-05-14-37-22_2_right_aileron_failure',
#  'carbonZ_2018-10-05-14-37-22_3_left_aileron_failure',
#  'carbonZ_2018-10-05-15-52-12_3_engine_failure_with_emr_traj',
#  'carbonZ_2018-10-05-15-55-10_engine_failure_with_emr_traj',
#  'carbonZ_2018-10-05-16-04-46_engine_failure_with_emr_traj',
#  'carbonZ_2018-10-18-11-03-57_engine_failure_with_emr_traj',
#  'carbonZ_2018-10-18-11-04-00_engine_failure_with_emr_traj',
#  'carbonZ_2018-10-18-11-04-08_1_engine_failure_with_emr_traj',
#  'carbonZ_2018-10-18-11-04-08_2_engine_failure_with_emr_traj',
#  'carbonZ_2018-10-18-11-04-35_engine_failure_with_emr_traj',
#  'carbonZ_2018-10-18-11-06-06_engine_failure_with_emr_traj',
#  'carbonZ_2018-09-11-17-27-13_1_rudder_zero_failure',
#  'carbonZ_2018-09-11-17-27-13_1_left_aileron_failure']

# %%
for flight_name in flight_topic_list:
    print(flight_name)
    dfs = df_dict[flight_name] 
    
    start_time = min(min(dfs[0].index),min(dfs[1].index),min(dfs[2].index),min(dfs[3].index),min(dfs[4].index),min(dfs[5].index),min(dfs[6].index),min(dfs[7].index),min(dfs[8].index),min(dfs[9].index),min(dfs[10].index),min(dfs[11].index),min(dfs[12].index))
    end_time = max(max(dfs[0].index),max(dfs[1].index),max(dfs[2].index),max(dfs[3].index),max(dfs[4].index),max(dfs[5].index),max(dfs[6].index),max(dfs[7].index),max(dfs[8].index),max(dfs[9].index),max(dfs[10].index),max(dfs[11].index),max(dfs[12].index))
    
    time_index = pd.date_range(start=start_time, end=end_time, freq="200ms")  
    data = [0] * len(time_index)

    df_failure = pd.DataFrame(data, index=time_index, columns=["failure_status"])

    failure_duration_start = failure_status_dict[flight_name][0]
    failure_duration_end   = failure_status_dict[flight_name][1]
    
    
    df_dict[flight_name].append(add_failure(flight_name,df_failure,failure_duration_start,failure_duration_end))
# Out:
# carbonZ_2018-07-18-15-53-31_1_engine_failure
# carbonZ_2018-07-18-15-53-31_2_engine_failure
# carbonZ_2018-07-18-16-22-01_engine_failure_with_emr_traj
# carbonZ_2018-07-18-16-37-39_2_engine_failure_with_emr_traj
# carbonZ_2018-07-30-16-29-45_engine_failure_with_emr_traj
# carbonZ_2018-07-30-16-39-00_1_engine_failure
# carbonZ_2018-07-30-16-39-00_2_engine_failure
# carbonZ_2018-07-30-17-10-45_engine_failure_with_emr_traj
# carbonZ_2018-07-30-17-20-01_engine_failure_with_emr_traj
# carbonZ_2018-07-30-17-36-35_engine_failure_with_emr_traj
# carbonZ_2018-07-30-17-46-31_engine_failure_with_emr_traj
# carbonZ_2018-09-11-11-56-30_engine_failure
# carbonZ_2018-09-11-14-22-07_1_engine_failure
# carbonZ_2018-09-11-14-22-07_2_engine_failure
# carbonZ_2018-09-11-14-41-51_elevator_failure
# carbonZ_2018-09-11-14-52-54_left_aileron__right_aileron__failure
# carbonZ_2018-09-11-15-05-11_1_elevator_failure
# carbonZ_2018-09-11-15-06-34_1_rudder_right_failure
# carbonZ_2018-09-11-15-06-34_2_rudder_right_failure
# carbonZ_2018-09-11-17-27-13_2_both_ailerons_failure
# carbonZ_2018-09-11-17-55-30_1_right_aileron_failure
# carbonZ_2018-09-11-17-55-30_2_left_aileron_failure
# carbonZ_2018-10-05-14-34-20_2_right_aileron_failure_with_emr_traj
# carbonZ_2018-10-05-14-37-22_2_right_aileron_failure
# carbonZ_2018-10-05-14-37-22_3_left_aileron_failure
# carbonZ_2018-10-05-15-52-12_3_engine_failure_with_emr_traj
# carbonZ_2018-10-05-15-55-10_engine_failure_with_emr_traj
# carbonZ_2018-10-05-16-04-46_engine_failure_with_emr_traj
# carbonZ_2018-10-18-11-03-57_engine_failure_with_emr_traj
# carbonZ_2018-10-18-11-04-00_engine_failure_with_emr_traj
# carbonZ_2018-10-18-11-04-08_1_engine_failure_with_emr_traj
# carbonZ_2018-10-18-11-04-08_2_engine_failure_with_emr_traj
# carbonZ_2018-10-18-11-04-35_engine_failure_with_emr_traj
# carbonZ_2018-10-18-11-06-06_engine_failure_with_emr_traj
# carbonZ_2018-09-11-17-27-13_1_rudder_zero_failure
# carbonZ_2018-09-11-17-27-13_1_left_aileron_failure

# %%
df = df_dict["carbonZ_2018-09-11-17-27-13_1_left_aileron_failure"]
df[12].iloc[: , :]
# Out:
#                                mavros-wind_estimation.twist.linear.x  \
# timestamp
# 2018-09-11 21:34:19.188548395                               0.360470
# 2018-09-11 21:34:19.566847897                               0.352583
# 2018-09-11 21:34:19.954091484                               0.345375
# 2018-09-11 21:34:20.421941571                               0.328750
# 2018-09-11 21:34:20.868431200                               0.321009
# ...                                                              ...
# 2018-09-11 21:36:40.589048991                              -0.256345
# 2018-09-11 21:36:40.936268682                              -0.255210
# 2018-09-11 21:36:41.422716742                              -0.253657
# 2018-09-11 21:36:41.785506158                              -0.252744
# 2018-09-11 21:36:42.286168071                              -0.252200
#
#                                mavros-wind_estimation.twist.linear.y  \
# timestamp
# 2018-09-11 21:34:19.188548395                               1.439026
# 2018-09-11 21:34:19.566847897                               1.463511
# 2018-09-11 21:34:19.954091484                               1.496819
# 2018-09-11 21:34:20.421941571                               1.548180
# 2018-09-11 21:34:20.868431200                               1.588851
# ...                                                              ...
# 2018-09-11 21:36:40.589048991                               2.252147
# 2018-09-11 21:36:40.936268682                               2.252631
# 2018-09-11 21:36:41.422716742                               2.253724
# 2018-09-11 21:36:41.785506158                               2.256600
# 2018-09-11 21:36:42.286168071                               2.260911
#
#                                mavros-wind_estimation.twist.linear.z
# timestamp
# 2018-09-11 21:34:19.188548395                                    0.0
# 2018-09-11 21:34:19.566847897                                    0.0
# 2018-09-11 21:34:19.954091484                                    0.0
# 2018-09-11 21:34:20.421941571                                    0.0
# 2018-09-11 21:34:20.868431200                                    0.0
# ...                                                              ...
# 2018-09-11 21:36:40.589048991                                    0.0
# 2018-09-11 21:36:40.936268682                                    0.0
# 2018-09-11 21:36:41.422716742                                    0.0
# 2018-09-11 21:36:41.785506158                                    0.0
# 2018-09-11 21:36:42.286168071                                    0.0
#
# [311 rows x 3 columns]

# %%
df = df_dict["carbonZ_2018-09-11-17-27-13_1_rudder_zero_failure"]
df[12]
# Out:
#                                mavros-wind_estimation.twist.linear.x  \
# timestamp
# 2018-09-11 21:34:19.188548395                               0.360470
# 2018-09-11 21:34:19.566847897                               0.352583
# 2018-09-11 21:34:19.954091484                               0.345375
# 2018-09-11 21:34:20.421941571                               0.328750
# 2018-09-11 21:34:20.868431200                               0.321009
# ...                                                              ...
# 2018-09-11 21:36:40.589048991                              -0.256345
# 2018-09-11 21:36:40.936268682                              -0.255210
# 2018-09-11 21:36:41.422716742                              -0.253657
# 2018-09-11 21:36:41.785506158                              -0.252744
# 2018-09-11 21:36:42.286168071                              -0.252200
#
#                                mavros-wind_estimation.twist.linear.y  \
# timestamp
# 2018-09-11 21:34:19.188548395                               1.439026
# 2018-09-11 21:34:19.566847897                               1.463511
# 2018-09-11 21:34:19.954091484                               1.496819
# 2018-09-11 21:34:20.421941571                               1.548180
# 2018-09-11 21:34:20.868431200                               1.588851
# ...                                                              ...
# 2018-09-11 21:36:40.589048991                               2.252147
# 2018-09-11 21:36:40.936268682                               2.252631
# 2018-09-11 21:36:41.422716742                               2.253724
# 2018-09-11 21:36:41.785506158                               2.256600
# 2018-09-11 21:36:42.286168071                               2.260911
#
#                                mavros-wind_estimation.twist.linear.z
# timestamp
# 2018-09-11 21:34:19.188548395                                    0.0
# 2018-09-11 21:34:19.566847897                                    0.0
# 2018-09-11 21:34:19.954091484                                    0.0
# 2018-09-11 21:34:20.421941571                                    0.0
# 2018-09-11 21:34:20.868431200                                    0.0
# ...                                                              ...
# 2018-09-11 21:36:40.589048991                                    0.0
# 2018-09-11 21:36:40.936268682                                    0.0
# 2018-09-11 21:36:41.422716742                                    0.0
# 2018-09-11 21:36:41.785506158                                    0.0
# 2018-09-11 21:36:42.286168071                                    0.0
#
# [311 rows x 3 columns]

# %%
for key, df in df_dict.items():
    print(key)
    print(len(df))
# Out:
# carbonZ_2018-07-18-15-53-31_1_engine_failure
# 14
# carbonZ_2018-07-18-15-53-31_2_engine_failure
# 14
# carbonZ_2018-07-18-16-22-01_engine_failure_with_emr_traj
# 14
# carbonZ_2018-07-18-16-37-39_2_engine_failure_with_emr_traj
# 14
# carbonZ_2018-07-30-16-29-45_engine_failure_with_emr_traj
# 14
# carbonZ_2018-07-30-16-39-00_1_engine_failure
# 14
# carbonZ_2018-07-30-16-39-00_2_engine_failure
# 14
# carbonZ_2018-07-30-17-10-45_engine_failure_with_emr_traj
# 14
# carbonZ_2018-07-30-17-20-01_engine_failure_with_emr_traj
# 14
# carbonZ_2018-07-30-17-36-35_engine_failure_with_emr_traj
# 14
# carbonZ_2018-07-30-17-46-31_engine_failure_with_emr_traj
# 14
# carbonZ_2018-09-11-11-56-30_engine_failure
# 14
# carbonZ_2018-09-11-14-22-07_1_engine_failure
# 14
# carbonZ_2018-09-11-14-22-07_2_engine_failure
# 14
# carbonZ_2018-09-11-14-41-51_elevator_failure
# 14
# carbonZ_2018-09-11-14-52-54_left_aileron__right_aileron__failure
# 14
# carbonZ_2018-09-11-15-05-11_1_elevator_failure
# 14
# carbonZ_2018-09-11-15-06-34_1_rudder_right_failure
# 14
# carbonZ_2018-09-11-15-06-34_2_rudder_right_failure
# 14
# carbonZ_2018-09-11-17-27-13_2_both_ailerons_failure
# 14
# carbonZ_2018-09-11-17-55-30_1_right_aileron_failure
# 14
# carbonZ_2018-09-11-17-55-30_2_left_aileron_failure
# 14
# carbonZ_2018-10-05-14-34-20_2_right_aileron_failure_with_emr_traj
# 14
# carbonZ_2018-10-05-14-37-22_2_right_aileron_failure
# 14
# carbonZ_2018-10-05-14-37-22_3_left_aileron_failure
# 14
# carbonZ_2018-10-05-15-52-12_3_engine_failure_with_emr_traj
# 14
# carbonZ_2018-10-05-15-55-10_engine_failure_with_emr_traj
# 14
# carbonZ_2018-10-05-16-04-46_engine_failure_with_emr_traj
# 14
# carbonZ_2018-10-18-11-03-57_engine_failure_with_emr_traj
# 14
# carbonZ_2018-10-18-11-04-00_engine_failure_with_emr_traj
# 14
# carbonZ_2018-10-18-11-04-08_1_engine_failure_with_emr_traj
# 14
# carbonZ_2018-10-18-11-04-08_2_engine_failure_with_emr_traj
# 14
# carbonZ_2018-10-18-11-04-35_engine_failure_with_emr_traj
# 14
# carbonZ_2018-10-18-11-06-06_engine_failure_with_emr_traj
# 14
# carbonZ_2018-09-11-17-27-13_1_rudder_zero_failure
# 14
# carbonZ_2018-09-11-17-27-13_1_left_aileron_failure
# 14

# %% [markdown]
# Birleştirme:

# %%
df = df_dict["carbonZ_2018-07-18-15-53-31_1_engine_failure"][1]
df
# Out:
#                                mavros-imu-atm_pressure.fluid_pressure
# timestamp
# 2018-07-18 19:56:50.883316762                            97310.498047
# 2018-07-18 19:56:50.958577559                            97310.498047
# 2018-07-18 19:56:51.062952770                            97329.193115
# 2018-07-18 19:56:51.153503583                            97341.693115
# 2018-07-18 19:56:51.245127118                            97329.223633
# ...                                                               ...
# 2018-07-18 19:59:02.784104260                            97410.662842
# 2018-07-18 19:59:02.886696084                            97414.984131
# 2018-07-18 19:59:02.954867820                            97414.984131
# 2018-07-18 19:59:03.072783613                            97418.975830
# 2018-07-18 19:59:03.128568663                            97418.975830
#
# [1323 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd

scaler = StandardScaler()

w_label = 66
s_label = 6

window_sizes = [661, 132, 32, 132, 247, 253, 253, 253, 247, 253, 27, 32, 27]
step_sizes =   [66, 13, 3, 13, 24, 25, 25, 25, 24, 25, 2, 3, 2]

x_arrays = [np.zeros((0, w, c)) for w, c in zip(window_sizes, [2, 1, 10, 1, 1, 4, 1, 1, 6, 1, 1, 6, 3])]
y = []

for key, data in df_dict.items():
    print(key)
    
    scaled_data = [pd.DataFrame(scaler.fit_transform(df), columns=df.columns, index=df.index).dropna() for df in data[:-1]]
    labels_data = data[-1]

    len_label = len(labels_data)
    len_data = [len(df) for df in scaled_data]

    while all(len_d - w >= 0 for len_d, w in zip(len_data, window_sizes)):
        labels = labels_data[len_label - w_label : len_label].values
        len_label -= s_label

        slices = [df[len_d - w : len_d].values for df, len_d, w in zip(scaled_data, len_data, window_sizes)]
        reshaped_slices = [
            sl.reshape(-1, w, c) for sl, w, c in zip(slices, window_sizes, [2, 1, 10, 1, 1, 4, 1, 1, 6, 1, 1, 6, 3])
        ]
        len_data = [len_d - s for len_d, s in zip(len_data, step_sizes)]

        if 2 in labels:
            repeat_count = 4
        elif 3 in labels:
            repeat_count = 3
        elif 4 in labels:
            repeat_count = 5
        else:
            repeat_count = 1
        
        for _ in range(repeat_count):
            for i, sl in enumerate(reshaped_slices):
                x_arrays[i] = np.vstack((x_arrays[i], sl))
            y.append(labels)
# Out:
# carbonZ_2018-07-18-15-53-31_1_engine_failure
# carbonZ_2018-07-18-15-53-31_2_engine_failure
# carbonZ_2018-07-18-16-22-01_engine_failure_with_emr_traj
# carbonZ_2018-07-18-16-37-39_2_engine_failure_with_emr_traj
# carbonZ_2018-07-30-16-29-45_engine_failure_with_emr_traj
# carbonZ_2018-07-30-16-39-00_1_engine_failure
# carbonZ_2018-07-30-16-39-00_2_engine_failure
# carbonZ_2018-07-30-17-10-45_engine_failure_with_emr_traj
# carbonZ_2018-07-30-17-20-01_engine_failure_with_emr_traj
# carbonZ_2018-07-30-17-36-35_engine_failure_with_emr_traj
# carbonZ_2018-07-30-17-46-31_engine_failure_with_emr_traj
# carbonZ_2018-09-11-11-56-30_engine_failure
# carbonZ_2018-09-11-14-22-07_1_engine_failure
# carbonZ_2018-09-11-14-22-07_2_engine_failure
# carbonZ_2018-09-11-14-41-51_elevator_failure
# carbonZ_2018-09-11-14-52-54_left_aileron__right_aileron__failure
# carbonZ_2018-09-11-15-05-11_1_elevator_failure
# carbonZ_2018-09-11-15-06-34_1_rudder_right_failure
# carbonZ_2018-09-11-15-06-34_2_rudder_right_failure
# carbonZ_2018-09-11-17-27-13_2_both_ailerons_failure
# carbonZ_2018-09-11-17-55-30_1_right_aileron_failure
# carbonZ_2018-09-11-17-55-30_2_left_aileron_failure
# carbonZ_2018-10-05-14-34-20_2_right_aileron_failure_with_emr_traj
# carbonZ_2018-10-05-14-37-22_2_right_aileron_failure
# carbonZ_2018-10-05-14-37-22_3_left_aileron_failure
# carbonZ_2018-10-05-15-52-12_3_engine_failure_with_emr_traj
# carbonZ_2018-10-05-15-55-10_engine_failure_with_emr_traj
# carbonZ_2018-10-05-16-04-46_engine_failure_with_emr_traj
# carbonZ_2018-10-18-11-03-57_engine_failure_with_emr_traj
# carbonZ_2018-10-18-11-04-00_engine_failure_with_emr_traj
# carbonZ_2018-10-18-11-04-08_1_engine_failure_with_emr_traj
# carbonZ_2018-10-18-11-04-08_2_engine_failure_with_emr_traj
# carbonZ_2018-10-18-11-04-35_engine_failure_with_emr_traj
# carbonZ_2018-10-18-11-06-06_engine_failure_with_emr_traj
# carbonZ_2018-09-11-17-27-13_1_rudder_zero_failure
# carbonZ_2018-09-11-17-27-13_1_left_aileron_failure

# %%
shapes = [x.shape for x in x_arrays]
shapes
# Out:
# [(3666, 661, 2),
#  (3666, 132, 1),
#  (3666, 32, 10),
#  (3666, 132, 1),
#  (3666, 247, 1),
#  (3666, 253, 4),
#  (3666, 253, 1),
#  (3666, 253, 1),
#  (3666, 247, 6),
#  (3666, 253, 1),
#  (3666, 27, 1),
#  (3666, 32, 6),
#  (3666, 27, 3)]

# %%
x_arrays[9][495][-1]
# Out:
# array([-1.2548107])

# %%
len(y)
# Out:
# 3666

# %%
y = np.array(y)
y_ = np.array([max(m) for m in y])
y_.shape,y.shape
# Out:
# ((3666, 1), (3666, 66, 1))

# %%
import random 

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True


set_seed(42)

# %%
import torch
from torch.utils.data import Dataset, DataLoader, random_split

class CustomDataset(Dataset):
    def __init__(self, x_arrays, y):
        self.x0 = torch.tensor(x_arrays[0], dtype=torch.float32)
        self.x1 = torch.tensor(x_arrays[1], dtype=torch.float32)
        self.x2 = torch.tensor(x_arrays[2], dtype=torch.float32)
        self.x3 = torch.tensor(x_arrays[3], dtype=torch.float32)
        self.x4 = torch.tensor(x_arrays[4], dtype=torch.float32)
        self.x5 = torch.tensor(x_arrays[5], dtype=torch.float32)
        self.x6 = torch.tensor(x_arrays[6], dtype=torch.float32)
        self.x7 = torch.tensor(x_arrays[7], dtype=torch.float32)
        self.x8 = torch.tensor(x_arrays[8], dtype=torch.float32)
        self.x9 = torch.tensor(x_arrays[9], dtype=torch.float32)
        self.x10 = torch.tensor(x_arrays[10], dtype=torch.float32)
        self.x11 = torch.tensor(x_arrays[11], dtype=torch.float32)
        self.x12 = torch.tensor(x_arrays[12], dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long).squeeze()

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return (
            self.x0[idx], self.x1[idx], self.x2[idx], self.x3[idx], self.x4[idx],
            self.x5[idx], self.x6[idx], self.x7[idx], self.x8[idx], self.x9[idx],
            self.x10[idx], self.x11[idx], self.x12[idx], self.y[idx]
        )

dataset = CustomDataset(x_arrays, y_)

train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

batch_size = 32
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

for batch in train_dataloader:
    (
        x0_batch, x1_batch, x2_batch, x3_batch, x4_batch, 
        x5_batch, x6_batch, x7_batch, x8_batch, x9_batch, 
        x10_batch, x11_batch, x12_batch, y_batch
    ) = batch
    print("Train batch shapes:", x0_batch.shape, x1_batch.shape, x2_batch.shape, x3_batch.shape, 
          x4_batch.shape, x5_batch.shape, x6_batch.shape, x7_batch.shape, x8_batch.shape, 
          x9_batch.shape, x10_batch.shape, x11_batch.shape, x12_batch.shape, y_batch.shape)
    break

for batch in test_dataloader:
    (
        x0_batch, x1_batch, x2_batch, x3_batch, x4_batch, 
        x5_batch, x6_batch, x7_batch, x8_batch, x9_batch, 
        x10_batch, x11_batch, x12_batch, y_batch
    ) = batch
    print("Test batch shapes:", x0_batch.shape, x1_batch.shape, x2_batch.shape, x3_batch.shape, 
          x4_batch.shape, x5_batch.shape, x6_batch.shape, x7_batch.shape, x8_batch.shape, 
          x9_batch.shape, x10_batch.shape, x11_batch.shape, x12_batch.shape, y_batch.shape)
    break
# Out:
# Train batch shapes: torch.Size([32, 661, 2]) torch.Size([32, 132, 1]) torch.Size([32, 32, 10]) torch.Size([32, 132, 1]) torch.Size([32, 247, 1]) torch.Size([32, 253, 4]) torch.Size([32, 253, 1]) torch.Size([32, 253, 1]) torch.Size([32, 247, 6]) torch.Size([32, 253, 1]) torch.Size([32, 27, 1]) torch.Size([32, 32, 6]) torch.Size([32, 27, 3]) torch.Size([32])
# Test batch shapes: torch.Size([32, 661, 2]) torch.Size([32, 132, 1]) torch.Size([32, 32, 10]) torch.Size([32, 132, 1]) torch.Size([32, 247, 1]) torch.Size([32, 253, 4]) torch.Size([32, 253, 1]) torch.Size([32, 253, 1]) torch.Size([32, 247, 6]) torch.Size([32, 253, 1]) torch.Size([32, 27, 1]) torch.Size([32, 32, 6]) torch.Size([32, 27, 3]) torch.Size([32])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class CausalConv1D(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, dilation=1, **kwargs):
        super(CausalConv1D, self).__init__()
        self.padding = (kernel_size - 1) * dilation
        self.conv = nn.Conv1d(in_channels, out_channels, kernel_size, padding=self.padding, dilation=dilation, **kwargs)

    def forward(self, x):
        x = self.conv(x)
        return x[:, :, :-self.padding]

class BlockDiagonal(nn.Module):
    def __init__(self, in_features, out_features, num_blocks):
        super(BlockDiagonal, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.num_blocks = num_blocks

        assert out_features % num_blocks == 0
        
        block_out_features = out_features // num_blocks
        
        self.blocks = nn.ModuleList([
            nn.Linear(in_features, block_out_features)
            for _ in range(num_blocks)
        ])
        
    def forward(self, x):
        x = [block(x) for block in self.blocks]
        x = torch.cat(x, dim=-1)
        return x

class sLSTMBlock(nn.Module):
    def __init__(self, input_size, head_size, num_heads, proj_factor=4/3):
        super(sLSTMBlock, self).__init__()
        self.input_size = input_size
        self.head_size = head_size
        self.hidden_size = head_size * num_heads
        self.num_heads = num_heads
        self.proj_factor = proj_factor

        assert proj_factor > 0

        self.layer_norm = nn.LayerNorm(input_size)
        self.causal_conv = CausalConv1D(1, 1, 4)

        self.Wz = BlockDiagonal(input_size, self.hidden_size, num_heads)
        self.Wi = BlockDiagonal(input_size, self.hidden_size, num_heads)
        self.Wf = BlockDiagonal(input_size, self.hidden_size, num_heads)
        self.Wo = BlockDiagonal(input_size, self.hidden_size, num_heads)

        self.Rz = BlockDiagonal(self.hidden_size, self.hidden_size, num_heads)
        self.Ri = BlockDiagonal(self.hidden_size, self.hidden_size, num_heads)
        self.Rf = BlockDiagonal(self.hidden_size, self.hidden_size, num_heads)
        self.Ro = BlockDiagonal(self.hidden_size, self.hidden_size, num_heads)

        self.group_norm = nn.GroupNorm(num_heads, self.hidden_size)

        self.up_proj_left = nn.Linear(self.hidden_size, int(self.hidden_size * proj_factor))
        self.up_proj_right = nn.Linear(self.hidden_size, int(self.hidden_size * proj_factor))
        self.down_proj = nn.Linear(int(self.hidden_size * proj_factor), input_size)

    def forward(self, x, prev_state):
        assert x.size(-1) == self.input_size
        h_prev, c_prev, n_prev, m_prev = prev_state

        h_prev = h_prev
        c_prev = c_prev
        n_prev = n_prev
        m_prev = m_prev
        
        x_norm = self.layer_norm(x)
        x_conv = F.silu(self.causal_conv(x_norm.unsqueeze(1)).squeeze(1))

        z = torch.tanh(self.Wz(x_norm) + self.Rz(h_prev))
        o = torch.sigmoid(self.Wo(x_norm) + self.Ro(h_prev))
        i_tilde = self.Wi(x_conv) + self.Ri(h_prev)
        f_tilde = self.Wf(x_conv) + self.Rf(h_prev)

        m_t = torch.max(f_tilde + m_prev, i_tilde)
        i = torch.exp(i_tilde - m_t)
        f = torch.exp(f_tilde + m_prev - m_t)

        c_t = f * c_prev + i * z
        n_t = f * n_prev + i
        h_t = o * c_t / n_t

        output = h_t
        output_norm = self.group_norm(output)
        output_left = self.up_proj_left(output_norm)
        output_right = self.up_proj_right(output_norm)
        output_gated = F.gelu(output_right)
        output = output_left * output_gated
        output = self.down_proj(output)
        final_output = output + x

        return final_output, (h_t, c_t, n_t, m_t)
    
class sLSTM(nn.Module):
    # TODO: Add bias, dropout, bidirectional
    def __init__(self, input_size, head_size, num_heads, num_layers=1, batch_first=False, proj_factor=4/3):
        super(sLSTM, self).__init__()
        self.input_size = input_size
        self.head_size = head_size
        self.hidden_size = head_size * num_heads
        self.num_heads = num_heads
        self.num_layers = num_layers
        self.batch_first = batch_first
        self.proj_factor_slstm = proj_factor

        self.layers = nn.ModuleList([sLSTMBlock(input_size, head_size, num_heads, proj_factor) for _ in range(num_layers)])

    def forward(self, x, state=None):
        assert x.ndim == 3
        if self.batch_first: x = x.transpose(0, 1)
        seq_len, batch_size, _ = x.size()
        
        if state is not None:
            state = torch.stack(list(state)).to(x.device)
            assert state.ndim == 4
            num_hidden, state_num_layers, state_batch_size, state_input_size = state.size()
            assert num_hidden == 4
            assert state_num_layers == self.num_layers
            assert state_batch_size == batch_size
            assert state_input_size == self.input_size
            state = state.transpose(0, 1)
        else:
            state = torch.zeros(self.num_layers, 4, batch_size, self.hidden_size, device=x.device)

        output = []
        for t in range(seq_len):
            x_t = x[t]
            for layer in range(self.num_layers):
                x_t, state_tuple = self.layers[layer](x_t, tuple(state[layer].clone()))
                state[layer] = torch.stack(list(state_tuple))
            output.append(x_t)
        
        output = torch.stack(output)
        if self.batch_first:
            output = output.transpose(0, 1)
        state = tuple(state.transpose(0, 1))
        return output, state

class mLSTMBlock(nn.Module):
    def __init__(self, input_size, head_size, num_heads, proj_factor=2):
        super(mLSTMBlock, self).__init__()
        self.input_size = input_size
        self.head_size = head_size
        self.hidden_size = head_size * num_heads
        self.num_heads = num_heads
        self.proj_factor = proj_factor

        assert proj_factor > 0

        self.layer_norm = nn.LayerNorm(input_size)
        self.up_proj_left = nn.Linear(input_size, int(input_size * proj_factor))
        self.up_proj_right = nn.Linear(input_size, self.hidden_size)
        self.down_proj = nn.Linear(self.hidden_size, input_size)

        self.causal_conv = CausalConv1D(1, 1, 4)
        self.skip_connection = nn.Linear(int(input_size * proj_factor), self.hidden_size)

        self.Wq = BlockDiagonal(int(input_size * proj_factor), self.hidden_size, num_heads)
        self.Wk = BlockDiagonal(int(input_size * proj_factor), self.hidden_size, num_heads)
        self.Wv = BlockDiagonal(int(input_size * proj_factor), self.hidden_size, num_heads)
        self.Wi = nn.Linear(int(input_size * proj_factor), self.hidden_size)
        self.Wf = nn.Linear(int(input_size * proj_factor), self.hidden_size)
        self.Wo = nn.Linear(int(input_size * proj_factor), self.hidden_size)

        self.group_norm = nn.GroupNorm(num_heads, self.hidden_size)

    def forward(self, x, prev_state):
        h_prev, c_prev, n_prev, m_prev = prev_state

        h_prev = h_prev
        c_prev = c_prev
        n_prev = n_prev
        m_prev = m_prev
        
        assert x.size(-1) == self.input_size
        x_norm = self.layer_norm(x)
        x_up_left = self.up_proj_left(x_norm)
        x_up_right = self.up_proj_right(x_norm)

        x_conv = F.silu(self.causal_conv(x_up_left.unsqueeze(1)).squeeze(1))
        x_skip = self.skip_connection(x_conv)

        q = self.Wq(x_conv)
        k = self.Wk(x_conv) / (self.head_size ** 0.5)
        v = self.Wv(x_up_left)

        i_tilde = self.Wi(x_conv)
        f_tilde = self.Wf(x_conv)
        o = torch.sigmoid(self.Wo(x_up_left))

        m_t = torch.max(f_tilde + m_prev, i_tilde)
        i = torch.exp(i_tilde - m_t)
        f = torch.exp(f_tilde + m_prev - m_t)

        c_t = f * c_prev + i * (v * k) # v @ k.T
        n_t = f * n_prev + i * k
        h_t = o * (c_t * q) / torch.max(torch.abs(n_t.T @ q), 1)[0] # o * (c @ q) / max{|n.T @ q|, 1}

        output = h_t
        output_norm = self.group_norm(output)
        output = output_norm + x_skip
        output = output * F.silu(x_up_right)
        output = self.down_proj(output)
        final_output = output + x

        return final_output, (h_t, c_t, n_t, m_t)
    
class mLSTM(nn.Module):
    # TODO: Add bias, dropout, bidirectional
    def __init__(self, input_size, head_size, num_heads, num_layers=1, batch_first=False, proj_factor=2):
        super(mLSTM, self).__init__()
        self.input_size = input_size
        self.head_size = head_size
        self.hidden_size = head_size * num_heads
        self.num_heads = num_heads
        self.num_layers = num_layers
        self.batch_first = batch_first
        self.proj_factor_slstm = proj_factor

        self.layers = nn.ModuleList([mLSTMBlock(input_size, head_size, num_heads, proj_factor) for _ in range(num_layers)])

    def forward(self, x, state=None):
        assert x.ndim == 3
        if self.batch_first: x = x.transpose(0, 1)
        seq_len, batch_size, _ = x.size()
        
        if state is not None:
            state = torch.stack(list(state))
            assert state.ndim == 4
            num_hidden, state_num_layers, state_batch_size, state_input_size = state.size()
            assert num_hidden == 4
            assert state_num_layers == self.num_layers
            assert state_batch_size == batch_size
            assert state_input_size == self.input_size
            state = state.transpose(0, 1)
        else:
            state = torch.zeros(self.num_layers, 4, batch_size, self.hidden_size, device=x.device)

        output = []
        for t in range(seq_len):
            x_t = x[t]
            for layer in range(self.num_layers):
                x_t, state_tuple = self.layers[layer](x_t, tuple(state[layer].clone()))
                state[layer] = torch.stack(list(state_tuple))
            output.append(x_t)
        
        output = torch.stack(output)
        if self.batch_first:
            output = output.transpose(0, 1)
        state = tuple(state.transpose(0, 1))
        return output, state



class xLSTM(nn.Module):
    # Added dropout and bias options
    def __init__(self, input_size, head_size, num_heads, layers, batch_first=False, 
                 proj_factor_slstm=4/3, proj_factor_mlstm=2, dropout=0.0):
        super(xLSTM, self).__init__()
        self.input_size = input_size
        self.head_size = head_size
        self.hidden_size = head_size * num_heads
        self.num_heads = num_heads
        self.layers = layers
        self.num_layers = len(layers)
        self.batch_first = batch_first
        self.proj_factor_slstm = proj_factor_slstm
        self.proj_factor_mlstm = proj_factor_mlstm
        self.dropout = dropout

        self.layers = nn.ModuleList()
        for layer_type in layers:
            if layer_type == 's':
                layer = sLSTMBlock(input_size, head_size, num_heads, proj_factor_slstm)
            elif layer_type == 'm':
                layer = mLSTMBlock(input_size, head_size, num_heads, proj_factor_mlstm)
            else:
                raise ValueError(f"Invalid layer type: {layer_type}. Choose 's' for sLSTM or 'm' for mLSTM.")
            self.layers.append(layer)

        self.dropout_layer = nn.Dropout(dropout) if dropout > 0 else None

    def forward(self, x, state=None):
        assert x.ndim == 3
        if self.batch_first: 
            x = x.transpose(0, 1)
        seq_len, batch_size, _ = x.size()
        
        if state is not None:
            state = torch.stack(list(state))
            assert state.ndim == 4
            num_hidden, state_num_layers, state_batch_size, state_input_size = state.size()
            assert num_hidden == 4
            assert state_num_layers == self.num_layers
            assert state_batch_size == batch_size
            assert state_input_size == self.input_size
            state = state.transpose(0, 1)
        else:
            state = torch.zeros(self.num_layers, 4, batch_size, self.hidden_size, device=x.device)

        output = []
        for t in range(seq_len):
            x_t = x[t]
            for layer in range(self.num_layers):
                x_t, state_tuple = self.layers[layer](x_t, tuple(state[layer].clone()))
                state[layer] = torch.stack(list(state_tuple))
                if self.dropout_layer is not None:
                    x_t = self.dropout_layer(x_t)
            output.append(x_t)
        
        output = torch.stack(output)
        if self.batch_first:
            output = output.transpose(0, 1)
        state = tuple(state.transpose(0, 1))
        return output, state

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class LSTMModel(nn.Module):
    def __init__(self, input_shapes, hidden_sizes, num_classes):
        super(LSTMModel, self).__init__()

        self.hidden_sizes = hidden_sizes

        self.lstm_layers = nn.ModuleList([
            xLSTM(input_shapes[i][2], hidden_sizes[i], layers=["s"], num_heads=1, batch_first=True,dropout=0.2)
            for i in range(13)
        ])

        self.flatten_size = self.get_flatten_size(input_shapes)

        self.fc = nn.Sequential(
            nn.Linear(self.flatten_size, 64),
            nn.ReLU(),
            nn.Linear(64, num_classes),
            nn.Softmax(dim=1)
        )

    def get_flatten_size(self, input_shapes):
        with torch.no_grad():
            x = [torch.zeros(1, input_shapes[i][1], input_shapes[i][2]) for i in range(13)]
         
            outputs = [self.lstm_layers[i](x[i])[0][:, -1, :].view(1, -1) for i in range(13)]
          
            flat_sizes = [output.shape[1] for output in outputs]
            return sum(flat_sizes)

    def forward(self, *inputs):
        
        lstm_outputs = [self.lstm_layers[i](inputs[i])[0][:, -1, :] for i in range(13)]

        out = torch.cat(lstm_outputs, dim=1)
        out = self.fc(out)

        return out


hidden_sizes = [16 for _ in range(13)]
input_shapes = [
    (3666, 661, 2),
    (3666, 132, 1),
    (3666, 32, 10),
    (3666, 132, 1),
    (3666, 247, 1),
    (3666, 253, 4),
    (3666, 253, 1),
    (3666, 253, 1),
    (3666, 247, 6),
    (3666, 253, 1),
    (3666, 27, 1),
    (3666, 32, 6),
    (3666, 27, 3)
]
num_classes = 5

model = LSTMModel(input_shapes, hidden_sizes, num_classes).to(device)
print(model)
# Out:
# LSTMModel(
#   (lstm_layers): ModuleList(
#     (0): xLSTM(
#       (layers): ModuleList(
#         (0): sLSTMBlock(
#           (layer_norm): LayerNorm((2,), eps=1e-05, elementwise_affine=True)
#           (causal_conv): CausalConv1D(
#             (conv): Conv1d(1, 1, kernel_size=(4,), stride=(1,), padding=(3,))
#           )
#           (Wz): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=2, out_features=16, bias=True)
#             )
#           )
#           (Wi): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=2, out_features=16, bias=True)
#             )
#           )
#           (Wf): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=2, out_features=16, bias=True)
#             )
#           )
#           (Wo): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=2, out_features=16, bias=True)
#             )
#           )
#           (Rz): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Ri): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Rf): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Ro): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (group_norm): GroupNorm(1, 16, eps=1e-05, affine=True)
#           (up_proj_left): Linear(in_features=16, out_features=21, bias=True)
#           (up_proj_right): Linear(in_features=16, out_features=21, bias=True)
#           (down_proj): Linear(in_features=21, out_features=2, bias=True)
#         )
#       )
#       (dropout_layer): Dropout(p=0.2, inplace=False)
#     )
#     (1): xLSTM(
#       (layers): ModuleList(
#         (0): sLSTMBlock(
#           (layer_norm): LayerNorm((1,), eps=1e-05, elementwise_affine=True)
#           (causal_conv): CausalConv1D(
#             (conv): Conv1d(1, 1, kernel_size=(4,), stride=(1,), padding=(3,))
#           )
#           (Wz): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=1, out_features=16, bias=True)
#             )
#           )
#           (Wi): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=1, out_features=16, bias=True)
#             )
#           )
#           (Wf): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=1, out_features=16, bias=True)
#             )
#           )
#           (Wo): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=1, out_features=16, bias=True)
#             )
#           )
#           (Rz): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Ri): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Rf): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Ro): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (group_norm): GroupNorm(1, 16, eps=1e-05, affine=True)
#           (up_proj_left): Linear(in_features=16, out_features=21, bias=True)
#           (up_proj_right): Linear(in_features=16, out_features=21, bias=True)
#           (down_proj): Linear(in_features=21, out_features=1, bias=True)
#         )
#       )
#       (dropout_layer): Dropout(p=0.2, inplace=False)
#     )
#     (2): xLSTM(
#       (layers): ModuleList(
#         (0): sLSTMBlock(
#           (layer_norm): LayerNorm((10,), eps=1e-05, elementwise_affine=True)
#           (causal_conv): CausalConv1D(
#             (conv): Conv1d(1, 1, kernel_size=(4,), stride=(1,), padding=(3,))
#           )
#           (Wz): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=10, out_features=16, bias=True)
#             )
#           )
#           (Wi): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=10, out_features=16, bias=True)
#             )
#           )
#           (Wf): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=10, out_features=16, bias=True)
#             )
#           )
#           (Wo): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=10, out_features=16, bias=True)
#             )
#           )
#           (Rz): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Ri): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Rf): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Ro): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (group_norm): GroupNorm(1, 16, eps=1e-05, affine=True)
#           (up_proj_left): Linear(in_features=16, out_features=21, bias=True)
#           (up_proj_right): Linear(in_features=16, out_features=21, bias=True)
#           (down_proj): Linear(in_features=21, out_features=10, bias=True)
#         )
#       )
#       (dropout_layer): Dropout(p=0.2, inplace=False)
#     )
#     (3-4): 2 x xLSTM(
#       (layers): ModuleList(
#         (0): sLSTMBlock(
#           (layer_norm): LayerNorm((1,), eps=1e-05, elementwise_affine=True)
#           (causal_conv): CausalConv1D(
#             (conv): Conv1d(1, 1, kernel_size=(4,), stride=(1,), padding=(3,))
#           )
#           (Wz): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=1, out_features=16, bias=True)
#             )
#           )
#           (Wi): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=1, out_features=16, bias=True)
#             )
#           )
#           (Wf): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=1, out_features=16, bias=True)
#             )
#           )
#           (Wo): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=1, out_features=16, bias=True)
#             )
#           )
#           (Rz): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Ri): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Rf): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Ro): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (group_norm): GroupNorm(1, 16, eps=1e-05, affine=True)
#           (up_proj_left): Linear(in_features=16, out_features=21, bias=True)
#           (up_proj_right): Linear(in_features=16, out_features=21, bias=True)
#           (down_proj): Linear(in_features=21, out_features=1, bias=True)
#         )
#       )
#       (dropout_layer): Dropout(p=0.2, inplace=False)
#     )
#     (5): xLSTM(
#       (layers): ModuleList(
#         (0): sLSTMBlock(
#           (layer_norm): LayerNorm((4,), eps=1e-05, elementwise_affine=True)
#           (causal_conv): CausalConv1D(
#             (conv): Conv1d(1, 1, kernel_size=(4,), stride=(1,), padding=(3,))
#           )
#           (Wz): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=4, out_features=16, bias=True)
#             )
#           )
#           (Wi): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=4, out_features=16, bias=True)
#             )
#           )
#           (Wf): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=4, out_features=16, bias=True)
#             )
#           )
#           (Wo): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=4, out_features=16, bias=True)
#             )
#           )
#           (Rz): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Ri): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Rf): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Ro): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (group_norm): GroupNorm(1, 16, eps=1e-05, affine=True)
#           (up_proj_left): Linear(in_features=16, out_features=21, bias=True)
#           (up_proj_right): Linear(in_features=16, out_features=21, bias=True)
#           (down_proj): Linear(in_features=21, out_features=4, bias=True)
#         )
#       )
#       (dropout_layer): Dropout(p=0.2, inplace=False)
#     )
#     (6-7): 2 x xLSTM(
#       (layers): ModuleList(
#         (0): sLSTMBlock(
#           (layer_norm): LayerNorm((1,), eps=1e-05, elementwise_affine=True)
#           (causal_conv): CausalConv1D(
#             (conv): Conv1d(1, 1, kernel_size=(4,), stride=(1,), padding=(3,))
#           )
#           (Wz): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=1, out_features=16, bias=True)
#             )
#           )
#           (Wi): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=1, out_features=16, bias=True)
#             )
#           )
#           (Wf): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=1, out_features=16, bias=True)
#             )
#           )
#           (Wo): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=1, out_features=16, bias=True)
#             )
#           )
#           (Rz): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Ri): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Rf): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Ro): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (group_norm): GroupNorm(1, 16, eps=1e-05, affine=True)
#           (up_proj_left): Linear(in_features=16, out_features=21, bias=True)
#           (up_proj_right): Linear(in_features=16, out_features=21, bias=True)
#           (down_proj): Linear(in_features=21, out_features=1, bias=True)
#         )
#       )
#       (dropout_layer): Dropout(p=0.2, inplace=False)
#     )
#     (8): xLSTM(
#       (layers): ModuleList(
#         (0): sLSTMBlock(
#           (layer_norm): LayerNorm((6,), eps=1e-05, elementwise_affine=True)
#           (causal_conv): CausalConv1D(
#             (conv): Conv1d(1, 1, kernel_size=(4,), stride=(1,), padding=(3,))
#           )
#           (Wz): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=6, out_features=16, bias=True)
#             )
#           )
#           (Wi): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=6, out_features=16, bias=True)
#             )
#           )
#           (Wf): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=6, out_features=16, bias=True)
#             )
#           )
#           (Wo): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=6, out_features=16, bias=True)
#             )
#           )
#           (Rz): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Ri): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Rf): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Ro): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (group_norm): GroupNorm(1, 16, eps=1e-05, affine=True)
#           (up_proj_left): Linear(in_features=16, out_features=21, bias=True)
#           (up_proj_right): Linear(in_features=16, out_features=21, bias=True)
#           (down_proj): Linear(in_features=21, out_features=6, bias=True)
#         )
#       )
#       (dropout_layer): Dropout(p=0.2, inplace=False)
#     )
#     (9-10): 2 x xLSTM(
#       (layers): ModuleList(
#         (0): sLSTMBlock(
#           (layer_norm): LayerNorm((1,), eps=1e-05, elementwise_affine=True)
#           (causal_conv): CausalConv1D(
#             (conv): Conv1d(1, 1, kernel_size=(4,), stride=(1,), padding=(3,))
#           )
#           (Wz): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=1, out_features=16, bias=True)
#             )
#           )
#           (Wi): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=1, out_features=16, bias=True)
#             )
#           )
#           (Wf): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=1, out_features=16, bias=True)
#             )
#           )
#           (Wo): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=1, out_features=16, bias=True)
#             )
#           )
#           (Rz): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Ri): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Rf): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Ro): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (group_norm): GroupNorm(1, 16, eps=1e-05, affine=True)
#           (up_proj_left): Linear(in_features=16, out_features=21, bias=True)
#           (up_proj_right): Linear(in_features=16, out_features=21, bias=True)
#           (down_proj): Linear(in_features=21, out_features=1, bias=True)
#         )
#       )
#       (dropout_layer): Dropout(p=0.2, inplace=False)
#     )
#     (11): xLSTM(
#       (layers): ModuleList(
#         (0): sLSTMBlock(
#           (layer_norm): LayerNorm((6,), eps=1e-05, elementwise_affine=True)
#           (causal_conv): CausalConv1D(
#             (conv): Conv1d(1, 1, kernel_size=(4,), stride=(1,), padding=(3,))
#           )
#           (Wz): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=6, out_features=16, bias=True)
#             )
#           )
#           (Wi): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=6, out_features=16, bias=True)
#             )
#           )
#           (Wf): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=6, out_features=16, bias=True)
#             )
#           )
#           (Wo): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=6, out_features=16, bias=True)
#             )
#           )
#           (Rz): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Ri): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Rf): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Ro): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (group_norm): GroupNorm(1, 16, eps=1e-05, affine=True)
#           (up_proj_left): Linear(in_features=16, out_features=21, bias=True)
#           (up_proj_right): Linear(in_features=16, out_features=21, bias=True)
#           (down_proj): Linear(in_features=21, out_features=6, bias=True)
#         )
#       )
#       (dropout_layer): Dropout(p=0.2, inplace=False)
#     )
#     (12): xLSTM(
#       (layers): ModuleList(
#         (0): sLSTMBlock(
#           (layer_norm): LayerNorm((3,), eps=1e-05, elementwise_affine=True)
#           (causal_conv): CausalConv1D(
#             (conv): Conv1d(1, 1, kernel_size=(4,), stride=(1,), padding=(3,))
#           )
#           (Wz): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=3, out_features=16, bias=True)
#             )
#           )
#           (Wi): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=3, out_features=16, bias=True)
#             )
#           )
#           (Wf): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=3, out_features=16, bias=True)
#             )
#           )
#           (Wo): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=3, out_features=16, bias=True)
#             )
#           )
#           (Rz): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Ri): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Rf): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (Ro): BlockDiagonal(
#             (blocks): ModuleList(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#             )
#           )
#           (group_norm): GroupNorm(1, 16, eps=1e-05, affine=True)
#           (up_proj_left): Linear(in_features=16, out_features=21, bias=True)
#           (up_proj_right): Linear(in_features=16, out_features=21, bias=True)
#           (down_proj): Linear(in_features=21, out_features=3, bias=True)
#         )
#       )
#       (dropout_layer): Dropout(p=0.2, inplace=False)
#     )
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=38, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=5, bias=True)
#     (3): Softmax(dim=1)
#   )
# )

# %%
import numpy as np
import torch

# Assuming y is a NumPy array or can be converted to one


num_samples_per_class = [np.sum(y_ == i) for i in range(5)]

total_samples = sum(num_samples_per_class)
class_weights = [total_samples / (5 * num_samples) for num_samples in num_samples_per_class]

weights = torch.tensor(class_weights, dtype=torch.float)
weights
# Out:
# tensor([0.3382, 2.3500, 3.5941, 0.8313, 7.3320])

# %%
import torch

class ModelCheckpoint:
    def __init__(self, filepath, monitor='val_loss', mode='min'):
        self.filepath = filepath
        self.monitor = monitor
        self.mode = mode
        self.best_score = None
        self.best_state_dict = None

        if mode == 'min':
            self.best_score = float('inf')
        else:
            self.best_score = float('-inf')

    def __call__(self, score, model_state_dict):
        if (self.mode == 'min' and score < self.best_score) or (self.mode == 'max' and score > self.best_score):
            print(f"Saving model with {self.monitor}: {score}")
            self.best_score = score
            self.best_state_dict = model_state_dict
            torch.save(model_state_dict, self.filepath)

    def get_best_state_dict(self):
        return self.best_state_dict

# %%
class EarlyStopping:
    def __init__(self, patience=5, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = None
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None:
            self.best_loss = val_loss
        elif val_loss > self.best_loss - self.min_delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_loss = val_loss
            self.counter = 0

# %%
# import torch.optim.lr_scheduler as lr_scheduler

# optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
# criterion = nn.CrossEntropyLoss(weight=weights)  # Assuming you're using CrossEntropyLoss for classification
# scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode="min",patience=30,factor=0.1)
# # scheduler = lr_scheduler.MultiStepLR(optimizer, milestones=[150,200], gamma=0.5)
# checkpoint = ModelCheckpoint(filepath='best_model.pth', monitor='val_loss', mode='min')

# %%
import torch.optim.lr_scheduler as lr_scheduler

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss(weight=weights).to(device)
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode="min",patience=5,factor=0.1)
checkpoint = ModelCheckpoint(filepath='best_model.pth', monitor='val_loss', mode='min')

# %%
import torch
import torch.optim as optim
import torch.nn as nn

train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

num_epochs = 60

for epoch in range(num_epochs):
    # Training
    model.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0

    for i, (x0_batch, x1_batch, x2_batch, x3_batch, x4_batch, 
        x5_batch, x6_batch, x7_batch, x8_batch, x9_batch, 
        x10_batch, x11_batch, x12_batch, y_batch) in enumerate(train_dataloader):

        optimizer.zero_grad()

        x0_batch, x1_batch, x2_batch, x3_batch, x4_batch,x5_batch, x6_batch, x7_batch, x8_batch, x9_batch, x10_batch, x11_batch, x12_batch, y_batch = (
            x0_batch.to(device),
            x1_batch.to(device),
            x2_batch.to(device),
            x3_batch.to(device),
            x4_batch.to(device),
            x5_batch.to(device),
            x6_batch.to(device),
            x7_batch.to(device),
            x8_batch.to(device),
            x9_batch.to(device),
            x10_batch.to(device),
            x11_batch.to(device),
            x12_batch.to(device),
            y_batch.to(device)
        )
        outputs = model(x0_batch, x1_batch, x2_batch, x3_batch, x4_batch, 
                         x5_batch, x6_batch, x7_batch, x8_batch, x9_batch, 
                         x10_batch, x11_batch, x12_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        
        _, predicted = torch.max(outputs, 1)
        total_train += y_batch.size(0)
        correct_train += (predicted == y_batch).sum().item()

        if i % 10 == 9:  
            print(f"Epoch {epoch + 1}, Batch {i + 1}, Training Loss: {running_loss / (i + 1)}, Training Accuracy: {(correct_train / total_train) * 100}%")
            
    train_epoch_loss = running_loss / len(train_dataloader)
    train_epoch_accuracy = (correct_train / total_train) * 100

    train_losses.append(train_epoch_loss)
    train_accuracies.append(train_epoch_accuracy)

    model.eval()
    correct_val = 0
    total_val = 0
    val_running_loss = 0.0
    with torch.no_grad():
        for x0_val, x1_val, x2_val, x3_val, x4_val, x5_val, x6_val, \
            x7_val, x8_val, x9_val, x10_val, x11_val, x12_val, y_val in test_dataloader:
            
            x0_val, x1_val, x2_val, x3_val, x4_val, \
            x5_val, x6_val, x7_val, x8_val, x9_val, \
            x10_val, x11_val, x12_val, y_val = (
                x0_val.to(device),
                x1_val.to(device),
                x2_val.to(device),
                x3_val.to(device),
                x4_val.to(device),
                x5_val.to(device),
                x6_val.to(device),
                x7_val.to(device),
                x8_val.to(device),
                x9_val.to(device),
                x10_val.to(device),
                x11_val.to(device),
                x12_val.to(device),
                y_val.to(device)
            )
            
            outputs = model(x0_val, x1_val, x2_val, x3_val, x4_val, 
                             x5_val, x6_val, x7_val, x8_val, x9_val, 
                             x10_val, x11_val, x12_val)
            loss = criterion(outputs, y_val)
            val_running_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            total_val += y_val.size(0)
            correct_val += (predicted == y_val).sum().item()

    scheduler.step(val_running_loss)

    val_epoch_loss = val_running_loss / len(test_dataloader)
    val_epoch_accuracy = (correct_val / total_val) * 100

    val_losses.append(val_epoch_loss)
    val_accuracies.append(val_epoch_accuracy)

    print(f"Epoch {epoch + 1}, Validation Loss: {val_epoch_loss}, Validation Accuracy: {val_epoch_accuracy}%")
    print(f"Epoch {epoch + 1}: Adam lr {optimizer.param_groups[0]['lr']:.4f}")

print("Training finished.")
# Out:
# Epoch 1, Batch 10, Training Loss: 1.6024322032928466, Training Accuracy: 37.8125%
# Epoch 1, Batch 20, Training Loss: 1.5940201818943023, Training Accuracy: 35.625%
# Epoch 1, Batch 30, Training Loss: 1.5909794012705485, Training Accuracy: 33.645833333333336%
# Epoch 1, Batch 40, Training Loss: 1.5779572188854218, Training Accuracy: 34.6875%
# Epoch 1, Batch 50, Training Loss: 1.5656051182746886, Training Accuracy: 34.4375%
# Epoch 1, Batch 60, Training Loss: 1.5523193637530008, Training Accuracy: 34.166666666666664%
# Epoch 1, Batch 70, Training Loss: 1.5398797631263732, Training Accuracy: 34.776785714285715%
# Epoch 1, Batch 80, Training Loss: 1.5245280623435975, Training Accuracy: 37.109375%
# Epoch 1, Batch 90, Training Loss: 1.5053534573978848, Training Accuracy: 40.38194444444444%
# Epoch 1, Validation Loss: 1.3345613479614258, Validation Accuracy: 68.80108991825612%
# Epoch 1: Adam lr 0.0010
# Epoch 2, Batch 10, Training Loss: 1.353585422039032, Training Accuracy: 62.18749999999999%
# Epoch 2, Batch 20, Training Loss: 1.3321559309959412, Training Accuracy: 61.875%
# Epoch 2, Batch 30, Training Loss: 1.3046236673990885, Training Accuracy: 63.95833333333333%
# Epoch 2, Batch 40, Training Loss: 1.2968121767044067, Training Accuracy: 64.140625%
# Epoch 2, Batch 50, Training Loss: 1.279488651752472, Training Accuracy: 64.6875%
# Epoch 2, Batch 60, Training Loss: 1.2666273057460784, Training Accuracy: 64.16666666666667%
# Epoch 2, Batch 70, Training Loss: 1.2503460935183934, Training Accuracy: 64.15178571428571%
# Epoch 2, Batch 80, Training Loss: 1.2420600041747094, Training Accuracy: 65.15625%
# Epoch 2, Batch 90, Training Loss: 1.23465635644065, Training Accuracy: 65.72916666666667%
# Epoch 2, Validation Loss: 1.0861364032911218, Validation Accuracy: 80.65395095367847%
# Epoch 2: Adam lr 0.0010
# Epoch 3, Batch 10, Training Loss: 1.1056109547615052, Training Accuracy: 78.4375%
# Epoch 3, Batch 20, Training Loss: 1.1003721415996552, Training Accuracy: 76.875%
# Epoch 3, Batch 30, Training Loss: 1.1060447553793589, Training Accuracy: 75.52083333333334%
# Epoch 3, Batch 40, Training Loss: 1.094467042386532, Training Accuracy: 75.78125%
# Epoch 3, Batch 50, Training Loss: 1.0894186186790467, Training Accuracy: 76.3125%
# Epoch 3, Batch 60, Training Loss: 1.0871082941691081, Training Accuracy: 76.875%
# Epoch 3, Batch 70, Training Loss: 1.0821815643991743, Training Accuracy: 76.83035714285714%
# Epoch 3, Batch 80, Training Loss: 1.077358864992857, Training Accuracy: 77.0703125%
# Epoch 3, Batch 90, Training Loss: 1.0751749760574765, Training Accuracy: 77.77777777777779%
# Epoch 3, Validation Loss: 1.0262429480967314, Validation Accuracy: 84.33242506811989%
# Epoch 3: Adam lr 0.0010
# Epoch 4, Batch 10, Training Loss: 1.049729233980179, Training Accuracy: 83.125%
# Epoch 4, Batch 20, Training Loss: 1.04559286236763, Training Accuracy: 81.40625%
# Epoch 4, Batch 30, Training Loss: 1.040424120426178, Training Accuracy: 81.97916666666667%
# Epoch 4, Batch 40, Training Loss: 1.0404039770364761, Training Accuracy: 82.34375%
# Epoch 4, Batch 50, Training Loss: 1.034445241689682, Training Accuracy: 83.0625%
# Epoch 4, Batch 60, Training Loss: 1.0350133687257768, Training Accuracy: 82.91666666666667%
# Epoch 4, Batch 70, Training Loss: 1.0356010224137988, Training Accuracy: 82.36607142857143%
# Epoch 4, Batch 80, Training Loss: 1.032472163438797, Training Accuracy: 82.34375%
# Epoch 4, Batch 90, Training Loss: 1.0320465710428026, Training Accuracy: 82.29166666666666%
# Epoch 4, Validation Loss: 1.006007264489713, Validation Accuracy: 86.10354223433242%
# Epoch 4: Adam lr 0.0010
# Epoch 5, Batch 10, Training Loss: 1.0117873072624206, Training Accuracy: 87.1875%
# Epoch 5, Batch 20, Training Loss: 1.0220935314893722, Training Accuracy: 85.46875%
# Epoch 5, Batch 30, Training Loss: 1.011701762676239, Training Accuracy: 86.77083333333333%
# Epoch 5, Batch 40, Training Loss: 1.0137956961989403, Training Accuracy: 86.25%
# Epoch 5, Batch 50, Training Loss: 1.0122849035263062, Training Accuracy: 85.4375%
# Epoch 5, Batch 60, Training Loss: 1.0139354854822158, Training Accuracy: 84.73958333333333%
# Epoch 5, Batch 70, Training Loss: 1.0115301609039307, Training Accuracy: 85.0%
# Epoch 5, Batch 80, Training Loss: 1.012891585379839, Training Accuracy: 85.0%
# Epoch 5, Batch 90, Training Loss: 1.0103879027896456, Training Accuracy: 85.3125%
# Epoch 5, Validation Loss: 0.991916324781335, Validation Accuracy: 87.73841961852861%
# Epoch 5: Adam lr 0.0010
# Epoch 6, Batch 10, Training Loss: 0.9950823366641999, Training Accuracy: 88.4375%
# Epoch 6, Batch 20, Training Loss: 1.01009661257267, Training Accuracy: 87.34375%
# Epoch 6, Batch 30, Training Loss: 0.9981968422730764, Training Accuracy: 88.54166666666666%
# Epoch 6, Batch 40, Training Loss: 1.0034100800752639, Training Accuracy: 86.953125%
# Epoch 6, Batch 50, Training Loss: 1.0039523792266847, Training Accuracy: 86.5625%
# Epoch 6, Batch 60, Training Loss: 1.0043952405452727, Training Accuracy: 85.9375%
# Epoch 6, Batch 70, Training Loss: 1.0018626494067056, Training Accuracy: 86.07142857142858%
# Epoch 6, Batch 80, Training Loss: 1.001625869423151, Training Accuracy: 86.25%
# Epoch 6, Batch 90, Training Loss: 1.0007824003696442, Training Accuracy: 86.11111111111111%
# Epoch 6, Validation Loss: 0.9758397884990858, Validation Accuracy: 87.19346049046321%
# Epoch 6: Adam lr 0.0010
# Epoch 7, Batch 10, Training Loss: 0.9884431838989258, Training Accuracy: 88.125%
# Epoch 7, Batch 20, Training Loss: 0.9762797206640244, Training Accuracy: 89.375%
# Epoch 7, Batch 30, Training Loss: 0.9753699203332266, Training Accuracy: 89.47916666666667%
# Epoch 7, Batch 40, Training Loss: 0.9785914078354836, Training Accuracy: 88.90625%
# Epoch 7, Batch 50, Training Loss: 0.9797870922088623, Training Accuracy: 88.75%
# Epoch 7, Batch 60, Training Loss: 0.9770843436320623, Training Accuracy: 89.16666666666667%
# Epoch 7, Batch 70, Training Loss: 0.9762208606515612, Training Accuracy: 89.46428571428572%
# Epoch 7, Batch 80, Training Loss: 0.9760965161025524, Training Accuracy: 89.296875%
# Epoch 7, Batch 90, Training Loss: 0.9793199764357673, Training Accuracy: 89.34027777777777%
# Epoch 7, Validation Loss: 0.9646298833515333, Validation Accuracy: 90.73569482288828%
# Epoch 7: Adam lr 0.0010
# Epoch 8, Batch 10, Training Loss: 0.9679619193077087, Training Accuracy: 90.625%
# Epoch 8, Batch 20, Training Loss: 0.969718137383461, Training Accuracy: 89.21875%
# Epoch 8, Batch 30, Training Loss: 0.9693142672379812, Training Accuracy: 89.6875%
# Epoch 8, Batch 40, Training Loss: 0.9698292508721351, Training Accuracy: 89.84375%
# Epoch 8, Batch 50, Training Loss: 0.9671897172927857, Training Accuracy: 90.5625%
# Epoch 8, Batch 60, Training Loss: 0.9685987631479899, Training Accuracy: 90.57291666666667%
# Epoch 8, Batch 70, Training Loss: 0.9659828662872314, Training Accuracy: 90.80357142857143%
# Epoch 8, Batch 80, Training Loss: 0.9673395305871964, Training Accuracy: 90.859375%
# Epoch 8, Batch 90, Training Loss: 0.9662908567322626, Training Accuracy: 91.18055555555556%
# Epoch 8, Validation Loss: 0.9553357725558074, Validation Accuracy: 92.09809264305177%
# Epoch 8: Adam lr 0.0010
# Epoch 9, Batch 10, Training Loss: 0.9792689621448517, Training Accuracy: 91.25%
# Epoch 9, Batch 20, Training Loss: 0.9652001798152924, Training Accuracy: 92.1875%
# Epoch 9, Batch 30, Training Loss: 0.972464938958486, Training Accuracy: 91.97916666666667%
# Epoch 9, Batch 40, Training Loss: 0.9664924323558808, Training Accuracy: 92.421875%
# Epoch 9, Batch 50, Training Loss: 0.9674296617507935, Training Accuracy: 92.75%
# Epoch 9, Batch 60, Training Loss: 0.9664204955101013, Training Accuracy: 92.44791666666666%
# Epoch 9, Batch 70, Training Loss: 0.9637990329946791, Training Accuracy: 92.45535714285714%
# Epoch 9, Batch 80, Training Loss: 0.9623244136571885, Training Accuracy: 92.578125%
# Epoch 9, Batch 90, Training Loss: 0.9633494608932072, Training Accuracy: 92.43055555555556%
# Epoch 9, Validation Loss: 0.9468063323394112, Validation Accuracy: 94.55040871934605%
# Epoch 9: Adam lr 0.0010
# Epoch 10, Batch 10, Training Loss: 0.9734308600425721, Training Accuracy: 94.0625%
# Epoch 10, Batch 20, Training Loss: 0.9625478386878967, Training Accuracy: 93.59375%
# Epoch 10, Batch 30, Training Loss: 0.95894988377889, Training Accuracy: 93.85416666666667%
# Epoch 10, Batch 40, Training Loss: 0.9594291135668754, Training Accuracy: 93.59375%
# Epoch 10, Batch 50, Training Loss: 0.9606642603874207, Training Accuracy: 93.4375%
# Epoch 10, Batch 60, Training Loss: 0.9596479465564092, Training Accuracy: 93.125%
# Epoch 10, Batch 70, Training Loss: 0.9556889797960009, Training Accuracy: 93.57142857142857%
# Epoch 10, Batch 80, Training Loss: 0.9559158027172089, Training Accuracy: 93.4375%
# Epoch 10, Batch 90, Training Loss: 0.9567979786131117, Training Accuracy: 93.4375%
# Epoch 10, Validation Loss: 0.9458768264107082, Validation Accuracy: 93.05177111716621%
# Epoch 10: Adam lr 0.0010
# Epoch 11, Batch 10, Training Loss: 0.9604553759098053, Training Accuracy: 91.25%
# Epoch 11, Batch 20, Training Loss: 0.9569746613502502, Training Accuracy: 92.96875%
# Epoch 11, Batch 30, Training Loss: 0.953598427772522, Training Accuracy: 92.8125%
# Epoch 11, Batch 40, Training Loss: 0.9509827241301536, Training Accuracy: 93.046875%
# Epoch 11, Batch 50, Training Loss: 0.9496001696586609, Training Accuracy: 93.3125%
# Epoch 11, Batch 60, Training Loss: 0.9506189495325088, Training Accuracy: 93.17708333333333%
# Epoch 11, Batch 70, Training Loss: 0.9500027792794364, Training Accuracy: 93.48214285714286%
# Epoch 11, Batch 80, Training Loss: 0.9504296697676182, Training Accuracy: 93.515625%
# Epoch 11, Batch 90, Training Loss: 0.949378392431471, Training Accuracy: 93.50694444444444%
# Epoch 11, Validation Loss: 0.938093988791756, Validation Accuracy: 95.77656675749319%
# Epoch 11: Adam lr 0.0010
# Epoch 12, Batch 10, Training Loss: 0.9388540625572205, Training Accuracy: 95.625%
# Epoch 12, Batch 20, Training Loss: 0.9444017946720124, Training Accuracy: 95.3125%
# Epoch 12, Batch 30, Training Loss: 0.9435072024663289, Training Accuracy: 94.79166666666666%
# Epoch 12, Batch 40, Training Loss: 0.9421648055315017, Training Accuracy: 95.0%
# Epoch 12, Batch 50, Training Loss: 0.9430455100536347, Training Accuracy: 94.9375%
# Epoch 12, Batch 60, Training Loss: 0.9421862045923869, Training Accuracy: 95.0%
# Epoch 12, Batch 70, Training Loss: 0.9434960101331983, Training Accuracy: 94.91071428571428%
# Epoch 12, Batch 80, Training Loss: 0.9448164299130439, Training Accuracy: 94.8046875%
# Epoch 12, Batch 90, Training Loss: 0.9452270719740126, Training Accuracy: 94.75694444444444%
# Epoch 12, Validation Loss: 0.9336038257764734, Validation Accuracy: 96.04904632152589%
# Epoch 12: Adam lr 0.0010
# Epoch 13, Batch 10, Training Loss: 0.9417551577091217, Training Accuracy: 95.625%
# Epoch 13, Batch 20, Training Loss: 0.9442008227109909, Training Accuracy: 95.46875%
# Epoch 13, Batch 30, Training Loss: 0.9439665218194325, Training Accuracy: 94.6875%
# Epoch 13, Batch 40, Training Loss: 0.9429120689630508, Training Accuracy: 94.84375%
# Epoch 13, Batch 50, Training Loss: 0.9452183306217193, Training Accuracy: 94.625%
# Epoch 13, Batch 60, Training Loss: 0.9456853975852331, Training Accuracy: 94.58333333333333%
# Epoch 13, Batch 70, Training Loss: 0.9447321576731545, Training Accuracy: 94.77678571428572%
# Epoch 13, Batch 80, Training Loss: 0.943406394124031, Training Accuracy: 94.8828125%
# Epoch 13, Batch 90, Training Loss: 0.9437930319044325, Training Accuracy: 94.89583333333333%
# Epoch 13, Validation Loss: 0.9384474598843119, Validation Accuracy: 94.82288828337875%
# Epoch 13: Adam lr 0.0010
# Epoch 14, Batch 10, Training Loss: 0.9374768793582916, Training Accuracy: 92.8125%
# Epoch 14, Batch 20, Training Loss: 0.9448696225881577, Training Accuracy: 93.90625%
# Epoch 14, Batch 30, Training Loss: 0.944225138425827, Training Accuracy: 94.6875%
# Epoch 14, Batch 40, Training Loss: 0.9461821213364601, Training Accuracy: 94.21875%
# Epoch 14, Batch 50, Training Loss: 0.9425804162025452, Training Accuracy: 94.5%
# Epoch 14, Batch 60, Training Loss: 0.9415759483973185, Training Accuracy: 94.53125%
# Epoch 14, Batch 70, Training Loss: 0.9425009701933179, Training Accuracy: 94.375%
# Epoch 14, Batch 80, Training Loss: 0.9431732922792435, Training Accuracy: 94.296875%
# Epoch 14, Batch 90, Training Loss: 0.9432354284657373, Training Accuracy: 94.27083333333334%
# Epoch 14, Validation Loss: 0.9360424021015996, Validation Accuracy: 95.64032697547684%
# Epoch 14: Adam lr 0.0010
# Epoch 15, Batch 10, Training Loss: 0.9423742771148682, Training Accuracy: 94.6875%
# Epoch 15, Batch 20, Training Loss: 0.9402759611606598, Training Accuracy: 95.0%
# Epoch 15, Batch 30, Training Loss: 0.9395727296670278, Training Accuracy: 95.20833333333333%
# Epoch 15, Batch 40, Training Loss: 0.9462879031896592, Training Accuracy: 94.609375%
# Epoch 15, Batch 50, Training Loss: 0.9464951860904693, Training Accuracy: 94.375%
# Epoch 15, Batch 60, Training Loss: 0.9432746917009354, Training Accuracy: 94.79166666666666%
# Epoch 15, Batch 70, Training Loss: 0.9433910437992641, Training Accuracy: 94.6875%
# Epoch 15, Batch 80, Training Loss: 0.9431488864123821, Training Accuracy: 94.609375%
# Epoch 15, Batch 90, Training Loss: 0.9412716673480139, Training Accuracy: 94.86111111111111%
# Epoch 15, Validation Loss: 0.9325396366741346, Validation Accuracy: 96.45776566757493%
# Epoch 15: Adam lr 0.0010
# Epoch 16, Batch 10, Training Loss: 0.9404073417186737, Training Accuracy: 94.6875%
# Epoch 16, Batch 20, Training Loss: 0.9405560076236725, Training Accuracy: 93.90625%
# Epoch 16, Batch 30, Training Loss: 0.9346532642841339, Training Accuracy: 95.20833333333333%
# Epoch 16, Batch 40, Training Loss: 0.9437116339802742, Training Accuracy: 94.921875%
# Epoch 16, Batch 50, Training Loss: 0.9423777675628662, Training Accuracy: 95.125%
# Epoch 16, Batch 60, Training Loss: 0.9418381214141845, Training Accuracy: 95.26041666666667%
# Epoch 16, Batch 70, Training Loss: 0.9421372073037284, Training Accuracy: 94.95535714285714%
# Epoch 16, Batch 80, Training Loss: 0.9400232389569283, Training Accuracy: 95.0390625%
# Epoch 16, Batch 90, Training Loss: 0.9398725416925219, Training Accuracy: 95.10416666666667%
# Epoch 16, Validation Loss: 0.9350910005362137, Validation Accuracy: 95.36784741144415%
# Epoch 16: Adam lr 0.0010
# Epoch 17, Batch 10, Training Loss: 0.9345586240291596, Training Accuracy: 95.625%
# Epoch 17, Batch 20, Training Loss: 0.9373244225978852, Training Accuracy: 95.625%
# Epoch 17, Batch 30, Training Loss: 0.9436623334884644, Training Accuracy: 95.20833333333333%
# Epoch 17, Batch 40, Training Loss: 0.941712249815464, Training Accuracy: 95.15625%
# Epoch 17, Batch 50, Training Loss: 0.93965576171875, Training Accuracy: 95.3125%
# Epoch 17, Batch 60, Training Loss: 0.9386544982592265, Training Accuracy: 95.52083333333333%
# Epoch 17, Batch 70, Training Loss: 0.9375853172370365, Training Accuracy: 95.66964285714286%
# Epoch 17, Batch 80, Training Loss: 0.936778774857521, Training Accuracy: 95.6640625%
# Epoch 17, Batch 90, Training Loss: 0.9368743744161394, Training Accuracy: 95.55555555555556%
# Epoch 17, Validation Loss: 0.9323964352193086, Validation Accuracy: 96.32152588555857%
# Epoch 17: Adam lr 0.0010
# Epoch 18, Batch 10, Training Loss: 0.9542809307575226, Training Accuracy: 94.6875%
# Epoch 18, Batch 20, Training Loss: 0.9482405960559845, Training Accuracy: 95.0%
# Epoch 18, Batch 30, Training Loss: 0.941165683666865, Training Accuracy: 95.72916666666667%
# Epoch 18, Batch 40, Training Loss: 0.9419555500149727, Training Accuracy: 95.15625%
# Epoch 18, Batch 50, Training Loss: 0.9421947550773621, Training Accuracy: 94.75%
# Epoch 18, Batch 60, Training Loss: 0.9401833931605021, Training Accuracy: 95.0%
# Epoch 18, Batch 70, Training Loss: 0.9385807531220572, Training Accuracy: 95.26785714285714%
# Epoch 18, Batch 80, Training Loss: 0.935669369250536, Training Accuracy: 95.625%
# Epoch 18, Batch 90, Training Loss: 0.9352915989028083, Training Accuracy: 95.69444444444444%
# Epoch 18, Validation Loss: 0.9314619484155074, Validation Accuracy: 96.45776566757493%
# Epoch 18: Adam lr 0.0010
# Epoch 19, Batch 10, Training Loss: 0.9276963293552398, Training Accuracy: 96.25%
# Epoch 19, Batch 20, Training Loss: 0.9300955027341843, Training Accuracy: 96.875%
# Epoch 19, Batch 30, Training Loss: 0.9312574942906697, Training Accuracy: 96.77083333333333%
# Epoch 19, Batch 40, Training Loss: 0.935172975063324, Training Accuracy: 95.859375%
# Epoch 19, Batch 50, Training Loss: 0.9343894374370575, Training Accuracy: 95.9375%
# Epoch 19, Batch 60, Training Loss: 0.9360456178585689, Training Accuracy: 95.83333333333334%
# Epoch 19, Batch 70, Training Loss: 0.9375534653663635, Training Accuracy: 95.53571428571429%
# Epoch 19, Batch 80, Training Loss: 0.9362942792475224, Training Accuracy: 95.625%
# Epoch 19, Batch 90, Training Loss: 0.9364684972498152, Training Accuracy: 95.69444444444444%
# Epoch 19, Validation Loss: 0.9309701504914657, Validation Accuracy: 96.59400544959128%
# Epoch 19: Adam lr 0.0010
# Epoch 20, Batch 10, Training Loss: 0.938253664970398, Training Accuracy: 96.25%
# Epoch 20, Batch 20, Training Loss: 0.9339186668395996, Training Accuracy: 96.09375%
# Epoch 20, Batch 30, Training Loss: 0.9290754675865174, Training Accuracy: 96.97916666666667%
# Epoch 20, Batch 40, Training Loss: 0.9280652165412903, Training Accuracy: 96.953125%
# Epoch 20, Batch 50, Training Loss: 0.931948539018631, Training Accuracy: 96.1875%
# Epoch 20, Batch 60, Training Loss: 0.9305816193421682, Training Accuracy: 96.45833333333333%
# Epoch 20, Batch 70, Training Loss: 0.9312198919909341, Training Accuracy: 96.38392857142857%
# Epoch 20, Batch 80, Training Loss: 0.9299838595092297, Training Accuracy: 96.484375%
# Epoch 20, Batch 90, Training Loss: 0.9307576000690461, Training Accuracy: 96.49305555555556%
# Epoch 20, Validation Loss: 0.930759917134824, Validation Accuracy: 96.59400544959128%
# Epoch 20: Adam lr 0.0010
# Epoch 21, Batch 10, Training Loss: 0.9300496816635132, Training Accuracy: 96.875%
# Epoch 21, Batch 20, Training Loss: 0.9325826406478882, Training Accuracy: 96.09375%
# Epoch 21, Batch 30, Training Loss: 0.9359319627285003, Training Accuracy: 95.83333333333334%
# Epoch 21, Batch 40, Training Loss: 0.9343323245644569, Training Accuracy: 96.09375%
# Epoch 21, Batch 50, Training Loss: 0.9335442650318145, Training Accuracy: 96.25%
# Epoch 21, Batch 60, Training Loss: 0.9358326623837153, Training Accuracy: 95.98958333333333%
# Epoch 21, Batch 70, Training Loss: 0.9367991762501853, Training Accuracy: 95.89285714285715%
# Epoch 21, Batch 80, Training Loss: 0.9343897745013237, Training Accuracy: 96.09375%
# Epoch 21, Batch 90, Training Loss: 0.9331421461370256, Training Accuracy: 96.18055555555556%
# Epoch 21, Validation Loss: 0.9323202578917794, Validation Accuracy: 97.00272479564033%
# Epoch 21: Adam lr 0.0010
# Epoch 22, Batch 10, Training Loss: 0.9344793677330017, Training Accuracy: 96.5625%
# Epoch 22, Batch 20, Training Loss: 0.9362926542758941, Training Accuracy: 96.25%
# Epoch 22, Batch 30, Training Loss: 0.9344444712003072, Training Accuracy: 96.25%
# Epoch 22, Batch 40, Training Loss: 0.9333875954151154, Training Accuracy: 96.25%
# Epoch 22, Batch 50, Training Loss: 0.9326530361175537, Training Accuracy: 96.25%
# Epoch 22, Batch 60, Training Loss: 0.9295634428660074, Training Accuracy: 96.5625%
# Epoch 22, Batch 70, Training Loss: 0.9277099217687335, Training Accuracy: 96.83035714285714%
# Epoch 22, Batch 80, Training Loss: 0.9295679204165935, Training Accuracy: 96.7578125%
# Epoch 22, Batch 90, Training Loss: 0.9316892961661021, Training Accuracy: 96.59722222222223%
# Epoch 22, Validation Loss: 0.9307257014772167, Validation Accuracy: 96.73024523160763%
# Epoch 22: Adam lr 0.0010
# Epoch 23, Batch 10, Training Loss: 0.9252865493297577, Training Accuracy: 96.875%
# Epoch 23, Batch 20, Training Loss: 0.928054478764534, Training Accuracy: 97.03125%
# Epoch 23, Batch 30, Training Loss: 0.9281802117824555, Training Accuracy: 97.1875%
# Epoch 23, Batch 40, Training Loss: 0.9294476762413979, Training Accuracy: 96.953125%
# Epoch 23, Batch 50, Training Loss: 0.926768057346344, Training Accuracy: 97.1875%
# Epoch 23, Batch 60, Training Loss: 0.9278294722239177, Training Accuracy: 97.03125%
# Epoch 23, Batch 70, Training Loss: 0.9289707609585354, Training Accuracy: 96.875%
# Epoch 23, Batch 80, Training Loss: 0.9285367548465728, Training Accuracy: 96.9921875%
# Epoch 23, Batch 90, Training Loss: 0.9293756730026669, Training Accuracy: 96.94444444444444%
# Epoch 23, Validation Loss: 0.9330972951391469, Validation Accuracy: 96.04904632152589%
# Epoch 23: Adam lr 0.0010
# Epoch 24, Batch 10, Training Loss: 0.9326461791992188, Training Accuracy: 95.0%
# Epoch 24, Batch 20, Training Loss: 0.9349196523427963, Training Accuracy: 95.625%
# Epoch 24, Batch 30, Training Loss: 0.932247418165207, Training Accuracy: 96.35416666666666%
# Epoch 24, Batch 40, Training Loss: 0.9321384534239769, Training Accuracy: 96.328125%
# Epoch 24, Batch 50, Training Loss: 0.9311338198184967, Training Accuracy: 96.3125%
# Epoch 24, Batch 60, Training Loss: 0.9309553404649099, Training Accuracy: 96.40625%
# Epoch 24, Batch 70, Training Loss: 0.9352887630462646, Training Accuracy: 95.9375%
# Epoch 24, Batch 80, Training Loss: 0.9342328608036041, Training Accuracy: 96.0546875%
# Epoch 24, Batch 90, Training Loss: 0.9356160892380608, Training Accuracy: 95.79861111111111%
# Epoch 24, Validation Loss: 0.9325160306432972, Validation Accuracy: 96.04904632152589%
# Epoch 24: Adam lr 0.0010
# Epoch 25, Batch 10, Training Loss: 0.9338540315628052, Training Accuracy: 95.3125%
# Epoch 25, Batch 20, Training Loss: 0.9364452451467514, Training Accuracy: 95.9375%
# Epoch 25, Batch 30, Training Loss: 0.9406988720099131, Training Accuracy: 95.52083333333333%
# Epoch 25, Batch 40, Training Loss: 0.9380569562315941, Training Accuracy: 95.703125%
# Epoch 25, Batch 50, Training Loss: 0.9381805264949798, Training Accuracy: 95.8125%
# Epoch 25, Batch 60, Training Loss: 0.9356882472832998, Training Accuracy: 95.83333333333334%
# Epoch 25, Batch 70, Training Loss: 0.9353004796164376, Training Accuracy: 95.84821428571428%
# Epoch 25, Batch 80, Training Loss: 0.9329861536622047, Training Accuracy: 96.1328125%
# Epoch 25, Batch 90, Training Loss: 0.9315565122498406, Training Accuracy: 96.38888888888889%
# Epoch 25, Validation Loss: 0.9320571370746779, Validation Accuracy: 96.45776566757493%
# Epoch 25: Adam lr 0.0010
# Epoch 26, Batch 10, Training Loss: 0.9351838588714599, Training Accuracy: 97.5%
# Epoch 26, Batch 20, Training Loss: 0.9305637389421463, Training Accuracy: 96.875%
# Epoch 26, Batch 30, Training Loss: 0.9367615381876627, Training Accuracy: 96.04166666666667%
# Epoch 26, Batch 40, Training Loss: 0.9409763932228088, Training Accuracy: 95.3125%
# Epoch 26, Batch 50, Training Loss: 0.9425847172737122, Training Accuracy: 95.25%
# Epoch 26, Batch 60, Training Loss: 0.9420288811127345, Training Accuracy: 95.20833333333333%
# Epoch 26, Batch 70, Training Loss: 0.9403883022921425, Training Accuracy: 95.35714285714286%
# Epoch 26, Batch 80, Training Loss: 0.9391448438167572, Training Accuracy: 95.5859375%
# Epoch 26, Batch 90, Training Loss: 0.9388736936781141, Training Accuracy: 95.55555555555556%
# Epoch 26, Validation Loss: 0.9323412050371584, Validation Accuracy: 96.04904632152589%
# Epoch 26: Adam lr 0.0001
# Epoch 27, Batch 10, Training Loss: 0.9389043152332306, Training Accuracy: 96.25%
# Epoch 27, Batch 20, Training Loss: 0.942368233203888, Training Accuracy: 95.625%
# Epoch 27, Batch 30, Training Loss: 0.9408371051152548, Training Accuracy: 95.72916666666667%
# Epoch 27, Batch 40, Training Loss: 0.9391366466879845, Training Accuracy: 95.9375%
# Epoch 27, Batch 50, Training Loss: 0.9388058257102966, Training Accuracy: 95.9375%
# Epoch 27, Batch 60, Training Loss: 0.9371304174264272, Training Accuracy: 95.88541666666667%
# Epoch 27, Batch 70, Training Loss: 0.934811019045966, Training Accuracy: 96.11607142857143%
# Epoch 27, Batch 80, Training Loss: 0.9333088956773281, Training Accuracy: 96.2890625%
# Epoch 27, Batch 90, Training Loss: 0.9327058348390791, Training Accuracy: 96.31944444444444%
# Epoch 27, Validation Loss: 0.9308013190393862, Validation Accuracy: 96.32152588555857%
# Epoch 27: Adam lr 0.0001
# Epoch 28, Batch 10, Training Loss: 0.9157394230365753, Training Accuracy: 98.125%
# Epoch 28, Batch 20, Training Loss: 0.9224990487098694, Training Accuracy: 97.5%
# Epoch 28, Batch 30, Training Loss: 0.9287268241246541, Training Accuracy: 96.77083333333333%
# Epoch 28, Batch 40, Training Loss: 0.9318873897194863, Training Accuracy: 96.40625%
# Epoch 28, Batch 50, Training Loss: 0.930319436788559, Training Accuracy: 96.5625%
# Epoch 28, Batch 60, Training Loss: 0.9291910290718078, Training Accuracy: 96.71875%
# Epoch 28, Batch 70, Training Loss: 0.9293301633426121, Training Accuracy: 96.69642857142857%
# Epoch 28, Batch 80, Training Loss: 0.9286304026842117, Training Accuracy: 96.71875%
# Epoch 28, Batch 90, Training Loss: 0.9281983978218502, Training Accuracy: 96.77083333333333%
# Epoch 28, Validation Loss: 0.9307590567547342, Validation Accuracy: 96.32152588555857%
# Epoch 28: Adam lr 0.0001
# Epoch 29, Batch 10, Training Loss: 0.9395486891269684, Training Accuracy: 96.5625%
# Epoch 29, Batch 20, Training Loss: 0.931064960360527, Training Accuracy: 96.71875%
# Epoch 29, Batch 30, Training Loss: 0.9302741547425588, Training Accuracy: 96.875%
# Epoch 29, Batch 40, Training Loss: 0.9288315102458, Training Accuracy: 96.875%
# Epoch 29, Batch 50, Training Loss: 0.9325706648826599, Training Accuracy: 96.4375%
# Epoch 29, Batch 60, Training Loss: 0.9320199231306712, Training Accuracy: 96.45833333333333%
# Epoch 29, Batch 70, Training Loss: 0.9334388537066324, Training Accuracy: 96.33928571428572%
# Epoch 29, Batch 80, Training Loss: 0.9323649451136589, Training Accuracy: 96.5234375%
# Epoch 29, Batch 90, Training Loss: 0.9315266880724166, Training Accuracy: 96.59722222222223%
# Epoch 29, Validation Loss: 0.930537620316381, Validation Accuracy: 96.45776566757493%
# Epoch 29: Adam lr 0.0001
# Epoch 30, Batch 10, Training Loss: 0.9220538258552551, Training Accuracy: 96.875%
# Epoch 30, Batch 20, Training Loss: 0.9303581058979035, Training Accuracy: 96.71875%
# Epoch 30, Batch 30, Training Loss: 0.9316920220851899, Training Accuracy: 96.77083333333333%
# Epoch 30, Batch 40, Training Loss: 0.9326291918754578, Training Accuracy: 96.796875%
# Epoch 30, Batch 50, Training Loss: 0.9305754709243774, Training Accuracy: 97.0%
# Epoch 30, Batch 60, Training Loss: 0.9294894893964132, Training Accuracy: 97.08333333333333%
# Epoch 30, Batch 70, Training Loss: 0.9300473741122655, Training Accuracy: 96.91964285714286%
# Epoch 30, Batch 80, Training Loss: 0.9301333852112293, Training Accuracy: 96.9140625%
# Epoch 30, Batch 90, Training Loss: 0.9290326760874854, Training Accuracy: 97.01388888888889%
# Epoch 30, Validation Loss: 0.9300859648248424, Validation Accuracy: 96.86648501362399%
# Epoch 30: Adam lr 0.0001
# Epoch 31, Batch 10, Training Loss: 0.9406501889228821, Training Accuracy: 95.0%
# Epoch 31, Batch 20, Training Loss: 0.9414813637733459, Training Accuracy: 96.09375%
# Epoch 31, Batch 30, Training Loss: 0.9347829441229503, Training Accuracy: 96.66666666666667%
# Epoch 31, Batch 40, Training Loss: 0.9338106736540794, Training Accuracy: 96.5625%
# Epoch 31, Batch 50, Training Loss: 0.9314984917640686, Training Accuracy: 96.8125%
# Epoch 31, Batch 60, Training Loss: 0.9305018067359925, Training Accuracy: 96.82291666666667%
# Epoch 31, Batch 70, Training Loss: 0.9296143685068403, Training Accuracy: 96.96428571428571%
# Epoch 31, Batch 80, Training Loss: 0.9298845089972019, Training Accuracy: 96.875%
# Epoch 31, Batch 90, Training Loss: 0.9287761608759563, Training Accuracy: 97.04861111111111%
# Epoch 31, Validation Loss: 0.9298855351365131, Validation Accuracy: 96.86648501362399%
# Epoch 31: Adam lr 0.0001
# Epoch 32, Batch 10, Training Loss: 0.9284052133560181, Training Accuracy: 97.8125%
# Epoch 32, Batch 20, Training Loss: 0.9283396691083908, Training Accuracy: 97.65625%
# Epoch 32, Batch 30, Training Loss: 0.9279454668362935, Training Accuracy: 97.39583333333334%
# Epoch 32, Batch 40, Training Loss: 0.9293385446071625, Training Accuracy: 97.109375%
# Epoch 32, Batch 50, Training Loss: 0.9292280280590057, Training Accuracy: 97.1875%
# Epoch 32, Batch 60, Training Loss: 0.9290342022975285, Training Accuracy: 97.1875%
# Epoch 32, Batch 70, Training Loss: 0.9292154857090541, Training Accuracy: 97.05357142857143%
# Epoch 32, Batch 80, Training Loss: 0.9288855038583279, Training Accuracy: 97.109375%
# Epoch 32, Batch 90, Training Loss: 0.9303872578673893, Training Accuracy: 96.97916666666667%
# Epoch 32, Validation Loss: 0.9298365297524825, Validation Accuracy: 96.86648501362399%
# Epoch 32: Adam lr 0.0001
# Epoch 33, Batch 10, Training Loss: 0.9244925558567048, Training Accuracy: 98.125%
# Epoch 33, Batch 20, Training Loss: 0.9277261942625046, Training Accuracy: 97.5%
# Epoch 33, Batch 30, Training Loss: 0.9275662541389466, Training Accuracy: 97.5%
# Epoch 33, Batch 40, Training Loss: 0.9258390605449677, Training Accuracy: 97.5%
# Epoch 33, Batch 50, Training Loss: 0.9254000401496887, Training Accuracy: 97.5%
# Epoch 33, Batch 60, Training Loss: 0.9277546246846516, Training Accuracy: 97.44791666666667%
# Epoch 33, Batch 70, Training Loss: 0.9289193877152034, Training Accuracy: 97.27678571428572%
# Epoch 33, Batch 80, Training Loss: 0.9275264121592045, Training Accuracy: 97.421875%
# Epoch 33, Batch 90, Training Loss: 0.9283746408091651, Training Accuracy: 97.32638888888889%
# Epoch 33, Validation Loss: 0.9294499469840009, Validation Accuracy: 96.86648501362399%
# Epoch 33: Adam lr 0.0001
# Epoch 34, Batch 10, Training Loss: 0.9210574388504028, Training Accuracy: 98.4375%
# Epoch 34, Batch 20, Training Loss: 0.9326852947473526, Training Accuracy: 97.1875%
# Epoch 34, Batch 30, Training Loss: 0.9286695659160614, Training Accuracy: 97.60416666666667%
# Epoch 34, Batch 40, Training Loss: 0.9309128850698472, Training Accuracy: 97.34375%
# Epoch 34, Batch 50, Training Loss: 0.9310112416744232, Training Accuracy: 97.1875%
# Epoch 34, Batch 60, Training Loss: 0.9292999555667242, Training Accuracy: 97.29166666666667%
# Epoch 34, Batch 70, Training Loss: 0.9294890071664538, Training Accuracy: 97.1875%
# Epoch 34, Batch 80, Training Loss: 0.9277444809675217, Training Accuracy: 97.3046875%
# Epoch 34, Batch 90, Training Loss: 0.9281032701333364, Training Accuracy: 97.25694444444444%
# Epoch 34, Validation Loss: 0.929650226364965, Validation Accuracy: 96.86648501362399%
# Epoch 34: Adam lr 0.0001
# Epoch 35, Batch 10, Training Loss: 0.9327660739421845, Training Accuracy: 95.9375%
# Epoch 35, Batch 20, Training Loss: 0.9264495313167572, Training Accuracy: 96.875%
# Epoch 35, Batch 30, Training Loss: 0.9298806289831797, Training Accuracy: 96.66666666666667%
# Epoch 35, Batch 40, Training Loss: 0.928692863881588, Training Accuracy: 96.953125%
# Epoch 35, Batch 50, Training Loss: 0.9297208309173584, Training Accuracy: 96.9375%
# Epoch 35, Batch 60, Training Loss: 0.9300316085418066, Training Accuracy: 97.03125%
# Epoch 35, Batch 70, Training Loss: 0.9274525982992989, Training Accuracy: 97.27678571428572%
# Epoch 35, Batch 80, Training Loss: 0.9265773445367813, Training Accuracy: 97.3828125%
# Epoch 35, Batch 90, Training Loss: 0.9263983872201708, Training Accuracy: 97.39583333333334%
# Epoch 35, Validation Loss: 0.9291712952696759, Validation Accuracy: 97.13896457765668%
# Epoch 35: Adam lr 0.0001
# Epoch 36, Batch 10, Training Loss: 0.9345314562320709, Training Accuracy: 96.875%
# Epoch 36, Batch 20, Training Loss: 0.9321642249822617, Training Accuracy: 97.03125%
# Epoch 36, Batch 30, Training Loss: 0.9311523795127868, Training Accuracy: 96.875%
# Epoch 36, Batch 40, Training Loss: 0.9286235839128494, Training Accuracy: 97.109375%
# Epoch 36, Batch 50, Training Loss: 0.9284324181079865, Training Accuracy: 97.25%
# Epoch 36, Batch 60, Training Loss: 0.9296797394752503, Training Accuracy: 97.13541666666666%
# Epoch 36, Batch 70, Training Loss: 0.9290071291582925, Training Accuracy: 97.23214285714286%
# Epoch 36, Batch 80, Training Loss: 0.928364111483097, Training Accuracy: 97.3046875%
# Epoch 36, Batch 90, Training Loss: 0.9280734241008759, Training Accuracy: 97.29166666666667%
# Epoch 36, Validation Loss: 0.9293886578601339, Validation Accuracy: 97.13896457765668%
# Epoch 36: Adam lr 0.0001
# Epoch 37, Batch 10, Training Loss: 0.9268337070941925, Training Accuracy: 96.875%
# Epoch 37, Batch 20, Training Loss: 0.9352560669183732, Training Accuracy: 96.5625%
# Epoch 37, Batch 30, Training Loss: 0.9337246735890706, Training Accuracy: 96.35416666666666%
# Epoch 37, Batch 40, Training Loss: 0.9346390441060066, Training Accuracy: 96.40625%
# Epoch 37, Batch 50, Training Loss: 0.9321959590911866, Training Accuracy: 96.6875%
# Epoch 37, Batch 60, Training Loss: 0.9300853788852692, Training Accuracy: 96.97916666666667%
# Epoch 37, Batch 70, Training Loss: 0.928645771741867, Training Accuracy: 97.1875%
# Epoch 37, Batch 80, Training Loss: 0.9287939362227917, Training Accuracy: 97.2265625%
# Epoch 37, Batch 90, Training Loss: 0.9280252118905385, Training Accuracy: 97.29166666666667%
# Epoch 37, Validation Loss: 0.9293600709541984, Validation Accuracy: 97.13896457765668%
# Epoch 37: Adam lr 0.0001
# Epoch 38, Batch 10, Training Loss: 0.9218353688716888, Training Accuracy: 97.5%
# Epoch 38, Batch 20, Training Loss: 0.9228195220232009, Training Accuracy: 97.65625%
# Epoch 38, Batch 30, Training Loss: 0.9287071665128072, Training Accuracy: 97.08333333333333%
# Epoch 38, Batch 40, Training Loss: 0.9287522807717323, Training Accuracy: 96.953125%
# Epoch 38, Batch 50, Training Loss: 0.9263226699829101, Training Accuracy: 97.1875%
# Epoch 38, Batch 60, Training Loss: 0.9273944675922394, Training Accuracy: 97.1875%
# Epoch 38, Batch 70, Training Loss: 0.9262710724558149, Training Accuracy: 97.32142857142857%
# Epoch 38, Batch 80, Training Loss: 0.9255283579230309, Training Accuracy: 97.4609375%
# Epoch 38, Batch 90, Training Loss: 0.9264316088623471, Training Accuracy: 97.36111111111111%
# Epoch 38, Validation Loss: 0.9289987242740133, Validation Accuracy: 97.00272479564033%
# Epoch 38: Adam lr 0.0001
# Epoch 39, Batch 10, Training Loss: 0.9262336432933808, Training Accuracy: 97.8125%
# Epoch 39, Batch 20, Training Loss: 0.9201633304357528, Training Accuracy: 98.28125%
# Epoch 39, Batch 30, Training Loss: 0.9211324691772461, Training Accuracy: 98.125%
# Epoch 39, Batch 40, Training Loss: 0.9237574845552444, Training Accuracy: 97.890625%
# Epoch 39, Batch 50, Training Loss: 0.9262259554862976, Training Accuracy: 97.6875%
# Epoch 39, Batch 60, Training Loss: 0.9252335647741954, Training Accuracy: 97.70833333333333%
# Epoch 39, Batch 70, Training Loss: 0.9259605160781316, Training Accuracy: 97.63392857142857%
# Epoch 39, Batch 80, Training Loss: 0.9263521157205105, Training Accuracy: 97.578125%
# Epoch 39, Batch 90, Training Loss: 0.9274420042832693, Training Accuracy: 97.39583333333334%
# Epoch 39, Validation Loss: 0.929040649662847, Validation Accuracy: 97.00272479564033%
# Epoch 39: Adam lr 0.0001
# Epoch 40, Batch 10, Training Loss: 0.9447535395622253, Training Accuracy: 95.3125%
# Epoch 40, Batch 20, Training Loss: 0.9332612752914429, Training Accuracy: 96.40625%
# Epoch 40, Batch 30, Training Loss: 0.9273821194966634, Training Accuracy: 97.08333333333333%
# Epoch 40, Batch 40, Training Loss: 0.9256811827421189, Training Accuracy: 97.421875%
# Epoch 40, Batch 50, Training Loss: 0.926683554649353, Training Accuracy: 97.375%
# Epoch 40, Batch 60, Training Loss: 0.9272560228904089, Training Accuracy: 97.23958333333333%
# Epoch 40, Batch 70, Training Loss: 0.9250871632780348, Training Accuracy: 97.5%
# Epoch 40, Batch 80, Training Loss: 0.9269509762525558, Training Accuracy: 97.421875%
# Epoch 40, Batch 90, Training Loss: 0.9269475493166182, Training Accuracy: 97.46527777777779%
# Epoch 40, Validation Loss: 0.9290470947390017, Validation Accuracy: 97.00272479564033%
# Epoch 40: Adam lr 0.0001
# Epoch 41, Batch 10, Training Loss: 0.9238533675670624, Training Accuracy: 97.8125%
# Epoch 41, Batch 20, Training Loss: 0.9365303605794907, Training Accuracy: 97.1875%
# Epoch 41, Batch 30, Training Loss: 0.9359738687674205, Training Accuracy: 96.97916666666667%
# Epoch 41, Batch 40, Training Loss: 0.9331904247403144, Training Accuracy: 96.875%
# Epoch 41, Batch 50, Training Loss: 0.9331389391422271, Training Accuracy: 96.875%
# Epoch 41, Batch 60, Training Loss: 0.9299460271994273, Training Accuracy: 97.23958333333333%
# Epoch 41, Batch 70, Training Loss: 0.9295094898768834, Training Accuracy: 97.27678571428572%
# Epoch 41, Batch 80, Training Loss: 0.9282067239284515, Training Accuracy: 97.3828125%
# Epoch 41, Batch 90, Training Loss: 0.9280659900771246, Training Accuracy: 97.43055555555556%
# Epoch 41, Validation Loss: 0.9288103399069413, Validation Accuracy: 97.00272479564033%
# Epoch 41: Adam lr 0.0001
# Epoch 42, Batch 10, Training Loss: 0.938761305809021, Training Accuracy: 96.5625%
# Epoch 42, Batch 20, Training Loss: 0.934030282497406, Training Accuracy: 96.875%
# Epoch 42, Batch 30, Training Loss: 0.9329625646273295, Training Accuracy: 96.77083333333333%
# Epoch 42, Batch 40, Training Loss: 0.9270636439323425, Training Accuracy: 97.34375%
# Epoch 42, Batch 50, Training Loss: 0.9265255331993103, Training Accuracy: 97.375%
# Epoch 42, Batch 60, Training Loss: 0.9258204698562622, Training Accuracy: 97.5%
# Epoch 42, Batch 70, Training Loss: 0.927342072554997, Training Accuracy: 97.45535714285715%
# Epoch 42, Batch 80, Training Loss: 0.9277276627719402, Training Accuracy: 97.421875%
# Epoch 42, Batch 90, Training Loss: 0.9277554637855954, Training Accuracy: 97.39583333333334%
# Epoch 42, Validation Loss: 0.9286725598832836, Validation Accuracy: 97.00272479564033%
# Epoch 42: Adam lr 0.0001
# Epoch 43, Batch 10, Training Loss: 0.9205880880355835, Training Accuracy: 97.8125%
# Epoch 43, Batch 20, Training Loss: 0.9275459796190262, Training Accuracy: 97.5%
# Epoch 43, Batch 30, Training Loss: 0.9272799372673035, Training Accuracy: 97.39583333333334%
# Epoch 43, Batch 40, Training Loss: 0.9278722897171974, Training Accuracy: 97.34375%
# Epoch 43, Batch 50, Training Loss: 0.9275232863426208, Training Accuracy: 97.375%
# Epoch 43, Batch 60, Training Loss: 0.9276954432328542, Training Accuracy: 97.23958333333333%
# Epoch 43, Batch 70, Training Loss: 0.9275493655885969, Training Accuracy: 97.36607142857143%
# Epoch 43, Batch 80, Training Loss: 0.9257390916347503, Training Accuracy: 97.578125%
# Epoch 43, Batch 90, Training Loss: 0.9261035588052537, Training Accuracy: 97.53472222222223%
# Epoch 43, Validation Loss: 0.9286621316619541, Validation Accuracy: 97.13896457765668%
# Epoch 43: Adam lr 0.0001
# Epoch 44, Batch 10, Training Loss: 0.9160959839820861, Training Accuracy: 98.4375%
# Epoch 44, Batch 20, Training Loss: 0.9179837554693222, Training Accuracy: 98.28125%
# Epoch 44, Batch 30, Training Loss: 0.9217480003833771, Training Accuracy: 98.02083333333333%
# Epoch 44, Batch 40, Training Loss: 0.9227816879749298, Training Accuracy: 97.96875%
# Epoch 44, Batch 50, Training Loss: 0.9238053774833679, Training Accuracy: 97.8125%
# Epoch 44, Batch 60, Training Loss: 0.9245112876097361, Training Accuracy: 97.65625%
# Epoch 44, Batch 70, Training Loss: 0.9252567487103599, Training Accuracy: 97.63392857142857%
# Epoch 44, Batch 80, Training Loss: 0.9256765328347683, Training Accuracy: 97.6171875%
# Epoch 44, Batch 90, Training Loss: 0.9267052875624763, Training Accuracy: 97.46527777777779%
# Epoch 44, Validation Loss: 0.9287141898403997, Validation Accuracy: 97.00272479564033%
# Epoch 44: Adam lr 0.0001
# Epoch 45, Batch 10, Training Loss: 0.9250045955181122, Training Accuracy: 97.5%
# Epoch 45, Batch 20, Training Loss: 0.9244048148393631, Training Accuracy: 97.34375%
# Epoch 45, Batch 30, Training Loss: 0.9289506574471792, Training Accuracy: 97.1875%
# Epoch 45, Batch 40, Training Loss: 0.9249620884656906, Training Accuracy: 97.578125%
# Epoch 45, Batch 50, Training Loss: 0.9251008367538452, Training Accuracy: 97.625%
# Epoch 45, Batch 60, Training Loss: 0.9261866947015126, Training Accuracy: 97.44791666666667%
# Epoch 45, Batch 70, Training Loss: 0.926534834929875, Training Accuracy: 97.5%
# Epoch 45, Batch 80, Training Loss: 0.9270891129970551, Training Accuracy: 97.5%
# Epoch 45, Batch 90, Training Loss: 0.9270887904696994, Training Accuracy: 97.46527777777779%
# Epoch 45, Validation Loss: 0.9283829642378766, Validation Accuracy: 97.41144414168937%
# Epoch 45: Adam lr 0.0001
# Epoch 46, Batch 10, Training Loss: 0.9438214838504791, Training Accuracy: 95.9375%
# Epoch 46, Batch 20, Training Loss: 0.9322380781173706, Training Accuracy: 97.03125%
# Epoch 46, Batch 30, Training Loss: 0.9265018939971924, Training Accuracy: 97.70833333333333%
# Epoch 46, Batch 40, Training Loss: 0.9274581745266914, Training Accuracy: 97.34375%
# Epoch 46, Batch 50, Training Loss: 0.9255586338043212, Training Accuracy: 97.5625%
# Epoch 46, Batch 60, Training Loss: 0.9252166867256164, Training Accuracy: 97.55208333333333%
# Epoch 46, Batch 70, Training Loss: 0.9257252556937081, Training Accuracy: 97.54464285714286%
# Epoch 46, Batch 80, Training Loss: 0.9258424066007137, Training Accuracy: 97.4609375%
# Epoch 46, Batch 90, Training Loss: 0.9264324208100637, Training Accuracy: 97.43055555555556%
# Epoch 46, Validation Loss: 0.9285632967948914, Validation Accuracy: 97.13896457765668%
# Epoch 46: Adam lr 0.0001
# Epoch 47, Batch 10, Training Loss: 0.9295869648456574, Training Accuracy: 97.1875%
# Epoch 47, Batch 20, Training Loss: 0.9267496049404145, Training Accuracy: 97.1875%
# Epoch 47, Batch 30, Training Loss: 0.9226803421974182, Training Accuracy: 97.70833333333333%
# Epoch 47, Batch 40, Training Loss: 0.924608190357685, Training Accuracy: 97.5%
# Epoch 47, Batch 50, Training Loss: 0.9226988351345062, Training Accuracy: 97.6875%
# Epoch 47, Batch 60, Training Loss: 0.9228257010380427, Training Accuracy: 97.65625%
# Epoch 47, Batch 70, Training Loss: 0.9246275850704738, Training Accuracy: 97.45535714285715%
# Epoch 47, Batch 80, Training Loss: 0.9250013932585717, Training Accuracy: 97.421875%
# Epoch 47, Batch 90, Training Loss: 0.9245166612995995, Training Accuracy: 97.5%
# Epoch 47, Validation Loss: 0.9281399250030518, Validation Accuracy: 97.27520435967303%
# Epoch 47: Adam lr 0.0001
# Epoch 48, Batch 10, Training Loss: 0.9407725512981415, Training Accuracy: 95.3125%
# Epoch 48, Batch 20, Training Loss: 0.9283420294523239, Training Accuracy: 96.875%
# Epoch 48, Batch 30, Training Loss: 0.9279732247193654, Training Accuracy: 97.08333333333333%
# Epoch 48, Batch 40, Training Loss: 0.9235195353627205, Training Accuracy: 97.65625%
# Epoch 48, Batch 50, Training Loss: 0.9233916807174682, Training Accuracy: 97.6875%
# Epoch 48, Batch 60, Training Loss: 0.9222690532604854, Training Accuracy: 97.8125%
# Epoch 48, Batch 70, Training Loss: 0.922721483026232, Training Accuracy: 97.90178571428572%
# Epoch 48, Batch 80, Training Loss: 0.9251011729240417, Training Accuracy: 97.5%
# Epoch 48, Batch 90, Training Loss: 0.9264150387710995, Training Accuracy: 97.36111111111111%
# Epoch 48, Validation Loss: 0.9280008751413097, Validation Accuracy: 97.27520435967303%
# Epoch 48: Adam lr 0.0001
# Epoch 49, Batch 10, Training Loss: 0.9405521392822266, Training Accuracy: 96.5625%
# Epoch 49, Batch 20, Training Loss: 0.9356908708810806, Training Accuracy: 97.34375%
# Epoch 49, Batch 30, Training Loss: 0.9288790166378021, Training Accuracy: 97.70833333333333%
# Epoch 49, Batch 40, Training Loss: 0.9267260417342186, Training Accuracy: 97.734375%
# Epoch 49, Batch 50, Training Loss: 0.9252008593082428, Training Accuracy: 97.8125%
# Epoch 49, Batch 60, Training Loss: 0.9293371836344401, Training Accuracy: 97.44791666666667%
# Epoch 49, Batch 70, Training Loss: 0.9281825704233987, Training Accuracy: 97.58928571428571%
# Epoch 49, Batch 80, Training Loss: 0.9290539786219597, Training Accuracy: 97.5%
# Epoch 49, Batch 90, Training Loss: 0.9281869219409095, Training Accuracy: 97.46527777777779%
# Epoch 49, Validation Loss: 0.9283574042112931, Validation Accuracy: 97.27520435967303%
# Epoch 49: Adam lr 0.0001
# Epoch 50, Batch 10, Training Loss: 0.9234483778476715, Training Accuracy: 97.8125%
# Epoch 50, Batch 20, Training Loss: 0.9272734522819519, Training Accuracy: 97.1875%
# Epoch 50, Batch 30, Training Loss: 0.9272139648596446, Training Accuracy: 97.29166666666667%
# Epoch 50, Batch 40, Training Loss: 0.9275661736726761, Training Accuracy: 97.1875%
# Epoch 50, Batch 50, Training Loss: 0.9263828611373901, Training Accuracy: 97.4375%
# Epoch 50, Batch 60, Training Loss: 0.9261376480261485, Training Accuracy: 97.44791666666667%
# Epoch 50, Batch 70, Training Loss: 0.9266599757330758, Training Accuracy: 97.32142857142857%
# Epoch 50, Batch 80, Training Loss: 0.9269643343985081, Training Accuracy: 97.3046875%
# Epoch 50, Batch 90, Training Loss: 0.9270542641480763, Training Accuracy: 97.29166666666667%
# Epoch 50, Validation Loss: 0.9284216709758925, Validation Accuracy: 97.27520435967303%
# Epoch 50: Adam lr 0.0001
# Epoch 51, Batch 10, Training Loss: 0.9385433197021484, Training Accuracy: 95.625%
# Epoch 51, Batch 20, Training Loss: 0.9376223534345627, Training Accuracy: 96.09375%
# Epoch 51, Batch 30, Training Loss: 0.9323324779669444, Training Accuracy: 96.66666666666667%
# Epoch 51, Batch 40, Training Loss: 0.9306019127368927, Training Accuracy: 96.796875%
# Epoch 51, Batch 50, Training Loss: 0.9274558544158935, Training Accuracy: 97.1875%
# Epoch 51, Batch 60, Training Loss: 0.9248752017815908, Training Accuracy: 97.5%
# Epoch 51, Batch 70, Training Loss: 0.9252339031015123, Training Accuracy: 97.5%
# Epoch 51, Batch 80, Training Loss: 0.9269438266754151, Training Accuracy: 97.3046875%
# Epoch 51, Batch 90, Training Loss: 0.9274999890062544, Training Accuracy: 97.22222222222221%
# Epoch 51, Validation Loss: 0.9285605912623198, Validation Accuracy: 97.27520435967303%
# Epoch 51: Adam lr 0.0001
# Epoch 52, Batch 10, Training Loss: 0.9250587463378906, Training Accuracy: 97.8125%
# Epoch 52, Batch 20, Training Loss: 0.9234540164470673, Training Accuracy: 97.96875%
# Epoch 52, Batch 30, Training Loss: 0.9252002875010172, Training Accuracy: 97.8125%
# Epoch 52, Batch 40, Training Loss: 0.9265737473964691, Training Accuracy: 97.65625%
# Epoch 52, Batch 50, Training Loss: 0.925872495174408, Training Accuracy: 97.8125%
# Epoch 52, Batch 60, Training Loss: 0.9262298285961151, Training Accuracy: 97.8125%
# Epoch 52, Batch 70, Training Loss: 0.9255947657993862, Training Accuracy: 97.8125%
# Epoch 52, Batch 80, Training Loss: 0.9255937829613685, Training Accuracy: 97.65625%
# Epoch 52, Batch 90, Training Loss: 0.9267997841040293, Training Accuracy: 97.5%
# Epoch 52, Validation Loss: 0.9280107073161913, Validation Accuracy: 97.41144414168937%
# Epoch 52: Adam lr 0.0001
# Epoch 53, Batch 10, Training Loss: 0.9275472164154053, Training Accuracy: 97.5%
# Epoch 53, Batch 20, Training Loss: 0.9247287660837173, Training Accuracy: 97.8125%
# Epoch 53, Batch 30, Training Loss: 0.92543372909228, Training Accuracy: 97.70833333333333%
# Epoch 53, Batch 40, Training Loss: 0.9293410107493401, Training Accuracy: 97.265625%
# Epoch 53, Batch 50, Training Loss: 0.9273665070533752, Training Accuracy: 97.4375%
# Epoch 53, Batch 60, Training Loss: 0.9278856158256531, Training Accuracy: 97.1875%
# Epoch 53, Batch 70, Training Loss: 0.9279357211930411, Training Accuracy: 97.1875%
# Epoch 53, Batch 80, Training Loss: 0.9273633837699891, Training Accuracy: 97.3046875%
# Epoch 53, Batch 90, Training Loss: 0.9271069977018568, Training Accuracy: 97.32638888888889%
# Epoch 53, Validation Loss: 0.9280392190684443, Validation Accuracy: 97.41144414168937%
# Epoch 53: Adam lr 0.0001
# Epoch 54, Batch 10, Training Loss: 0.9334532558918, Training Accuracy: 97.1875%
# Epoch 54, Batch 20, Training Loss: 0.9324086427688598, Training Accuracy: 97.1875%
# Epoch 54, Batch 30, Training Loss: 0.9297225952148438, Training Accuracy: 97.5%
# Epoch 54, Batch 40, Training Loss: 0.9265316247940063, Training Accuracy: 97.734375%
# Epoch 54, Batch 50, Training Loss: 0.9258129453659057, Training Accuracy: 97.75%
# Epoch 54, Batch 60, Training Loss: 0.9250448087851206, Training Accuracy: 97.86458333333333%
# Epoch 54, Batch 70, Training Loss: 0.9259683890002114, Training Accuracy: 97.67857142857143%
# Epoch 54, Batch 80, Training Loss: 0.9263999089598656, Training Accuracy: 97.6171875%
# Epoch 54, Batch 90, Training Loss: 0.9260455310344696, Training Accuracy: 97.63888888888889%
# Epoch 54, Validation Loss: 0.9279124477635259, Validation Accuracy: 97.41144414168937%
# Epoch 54: Adam lr 0.0000
# Epoch 55, Batch 10, Training Loss: 0.9181290984153747, Training Accuracy: 97.5%
# Epoch 55, Batch 20, Training Loss: 0.9189773976802826, Training Accuracy: 97.65625%
# Epoch 55, Batch 30, Training Loss: 0.9197855194409689, Training Accuracy: 97.60416666666667%
# Epoch 55, Batch 40, Training Loss: 0.9287022799253464, Training Accuracy: 96.953125%
# Epoch 55, Batch 50, Training Loss: 0.928602020740509, Training Accuracy: 97.0%
# Epoch 55, Batch 60, Training Loss: 0.9275606801112493, Training Accuracy: 97.08333333333333%
# Epoch 55, Batch 70, Training Loss: 0.9271730065345765, Training Accuracy: 97.00892857142858%
# Epoch 55, Batch 80, Training Loss: 0.9266658455133439, Training Accuracy: 97.1484375%
# Epoch 55, Batch 90, Training Loss: 0.9260231229994033, Training Accuracy: 97.22222222222221%
# Epoch 55, Validation Loss: 0.9278492150099381, Validation Accuracy: 97.41144414168937%
# Epoch 55: Adam lr 0.0000
# Epoch 56, Batch 10, Training Loss: 0.9147097289562225, Training Accuracy: 98.75%
# Epoch 56, Batch 20, Training Loss: 0.9180893748998642, Training Accuracy: 98.4375%
# Epoch 56, Batch 30, Training Loss: 0.9211419741312663, Training Accuracy: 98.22916666666667%
# Epoch 56, Batch 40, Training Loss: 0.9218419447541237, Training Accuracy: 97.96875%
# Epoch 56, Batch 50, Training Loss: 0.9229630208015442, Training Accuracy: 97.75%
# Epoch 56, Batch 60, Training Loss: 0.9248348226149877, Training Accuracy: 97.55208333333333%
# Epoch 56, Batch 70, Training Loss: 0.9245048412254878, Training Accuracy: 97.58928571428571%
# Epoch 56, Batch 80, Training Loss: 0.924716155976057, Training Accuracy: 97.6953125%
# Epoch 56, Batch 90, Training Loss: 0.9252900838851928, Training Accuracy: 97.53472222222223%
# Epoch 56, Validation Loss: 0.9278233077215112, Validation Accuracy: 97.41144414168937%
# Epoch 56: Adam lr 0.0000
# Epoch 57, Batch 10, Training Loss: 0.9363788068294525, Training Accuracy: 96.25%
# Epoch 57, Batch 20, Training Loss: 0.9299007326364517, Training Accuracy: 97.1875%
# Epoch 57, Batch 30, Training Loss: 0.9251157840092977, Training Accuracy: 97.39583333333334%
# Epoch 57, Batch 40, Training Loss: 0.9287876158952713, Training Accuracy: 97.03125%
# Epoch 57, Batch 50, Training Loss: 0.9276993787288665, Training Accuracy: 97.1875%
# Epoch 57, Batch 60, Training Loss: 0.9281992544730504, Training Accuracy: 97.13541666666666%
# Epoch 57, Batch 70, Training Loss: 0.9266776655401502, Training Accuracy: 97.32142857142857%
# Epoch 57, Batch 80, Training Loss: 0.9259562149643898, Training Accuracy: 97.3828125%
# Epoch 57, Batch 90, Training Loss: 0.9253126435809665, Training Accuracy: 97.5%
# Epoch 57, Validation Loss: 0.9278183112973752, Validation Accuracy: 97.41144414168937%
# Epoch 57: Adam lr 0.0000
# Epoch 58, Batch 10, Training Loss: 0.9254667460918427, Training Accuracy: 98.125%
# Epoch 58, Batch 20, Training Loss: 0.9275973349809646, Training Accuracy: 97.5%
# Epoch 58, Batch 30, Training Loss: 0.9263467212518056, Training Accuracy: 97.60416666666667%
# Epoch 58, Batch 40, Training Loss: 0.92581048309803, Training Accuracy: 97.5%
# Epoch 58, Batch 50, Training Loss: 0.9259579396247863, Training Accuracy: 97.375%
# Epoch 58, Batch 60, Training Loss: 0.9248829583326975, Training Accuracy: 97.39583333333334%
# Epoch 58, Batch 70, Training Loss: 0.9260900012084416, Training Accuracy: 97.32142857142857%
# Epoch 58, Batch 80, Training Loss: 0.9254275463521481, Training Accuracy: 97.3828125%
# Epoch 58, Batch 90, Training Loss: 0.9257486257288191, Training Accuracy: 97.32638888888889%
# Epoch 58, Validation Loss: 0.9277812968129697, Validation Accuracy: 97.41144414168937%
# Epoch 58: Adam lr 0.0000
# Epoch 59, Batch 10, Training Loss: 0.9339035332202912, Training Accuracy: 96.25%
# Epoch 59, Batch 20, Training Loss: 0.9340891152620315, Training Accuracy: 96.875%
# Epoch 59, Batch 30, Training Loss: 0.9274200816949209, Training Accuracy: 97.39583333333334%
# Epoch 59, Batch 40, Training Loss: 0.9246382981538772, Training Accuracy: 97.578125%
# Epoch 59, Batch 50, Training Loss: 0.9271043694019317, Training Accuracy: 97.5%
# Epoch 59, Batch 60, Training Loss: 0.9265858262777329, Training Accuracy: 97.39583333333334%
# Epoch 59, Batch 70, Training Loss: 0.926681102173669, Training Accuracy: 97.23214285714286%
# Epoch 59, Batch 80, Training Loss: 0.9256700232625008, Training Accuracy: 97.421875%
# Epoch 59, Batch 90, Training Loss: 0.9265392654471927, Training Accuracy: 97.36111111111111%
# Epoch 59, Validation Loss: 0.9277295625728109, Validation Accuracy: 97.41144414168937%
# Epoch 59: Adam lr 0.0000
# Epoch 60, Batch 10, Training Loss: 0.9248744070529937, Training Accuracy: 97.1875%
# Epoch 60, Batch 20, Training Loss: 0.921591866016388, Training Accuracy: 97.8125%
# Epoch 60, Batch 30, Training Loss: 0.9242979506651561, Training Accuracy: 97.5%
# Epoch 60, Batch 40, Training Loss: 0.9254336804151535, Training Accuracy: 97.421875%
# Epoch 60, Batch 50, Training Loss: 0.9258443140983581, Training Accuracy: 97.4375%
# Epoch 60, Batch 60, Training Loss: 0.9255515694618225, Training Accuracy: 97.55208333333333%
# Epoch 60, Batch 70, Training Loss: 0.9258739760943822, Training Accuracy: 97.63392857142857%
# Epoch 60, Batch 80, Training Loss: 0.9255635559558868, Training Accuracy: 97.6953125%
# Epoch 60, Batch 90, Training Loss: 0.9259940432177649, Training Accuracy: 97.5%
# Epoch 60, Validation Loss: 0.9276895341665848, Validation Accuracy: 97.41144414168937%
# Epoch 60: Adam lr 0.0000
# Training finished.

# %%
plt.plot(train_accuracies, label='Training Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

def evaluate_model(model, dataloader):
    model.eval()
    all_predictions = []
    all_targets = []

    with torch.no_grad():
        for x0_batch, x1_batch, x2_batch, x3_batch, x4_batch, \
            x5_batch, x6_batch, x7_batch, x8_batch, x9_batch, \
            x10_batch, x11_batch, x12_batch, y_batch in dataloader:
            
            x0_batch, x1_batch, x2_batch, x3_batch, x4_batch, \
            x5_batch, x6_batch, x7_batch, x8_batch, x9_batch, \
            x10_batch, x11_batch, x12_batch, y_batch = (
                x0_batch.to(device),
                x1_batch.to(device),
                x2_batch.to(device),
                x3_batch.to(device),
                x4_batch.to(device),
                x5_batch.to(device),
                x6_batch.to(device),
                x7_batch.to(device),
                x8_batch.to(device),
                x9_batch.to(device),
                x10_batch.to(device),
                x11_batch.to(device),
                x12_batch.to(device),
                y_batch.to(device)
            )
            
            outputs = model(x0_batch, x1_batch, x2_batch, x3_batch, x4_batch, 
                             x5_batch, x6_batch, x7_batch, x8_batch, x9_batch, 
                             x10_batch, x11_batch, x12_batch)
            
            _, predicted = torch.max(outputs, 1)
            
            all_predictions.extend(predicted.cpu().numpy())
            all_targets.extend(y_batch.cpu().numpy())

    # Compute metrics
    accuracy = accuracy_score(all_targets, all_predictions)
    conf_matrix = confusion_matrix(all_targets, all_predictions)
    class_report = classification_report(all_targets, all_predictions, zero_division=0)

    return accuracy, conf_matrix, class_report

# %%
accuracy, conf_matrix, class_report = evaluate_model(model, test_dataloader)

print(f'Validation Accuracy: {accuracy}\n')
print(f'Confusion Matrix:\n{conf_matrix}\n')
print(f'Classification Report:\n{class_report}\n')
# Out:
# Validation Accuracy: 0.9741144414168937
#
# Confusion Matrix:
# [[416   1   0   3   0]
#  [  1  79   0   0   0]
#  [  0   0  34   0   0]
#  [  2   0  12 168   0]
#  [  0   0   0   0  18]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       420
#            1       0.99      0.99      0.99        80
#            2       0.74      1.00      0.85        34
#            3       0.98      0.92      0.95       182
#            4       1.00      1.00      1.00        18
#
#     accuracy                           0.97       734
#    macro avg       0.94      0.98      0.96       734
# weighted avg       0.98      0.97      0.97       734
